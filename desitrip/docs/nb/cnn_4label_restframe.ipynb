# %% [markdown]
# # CNN Classifier Training Example
#
# This notebook demonstrates a basic 4-layer CNN trained to classify spectra from galaxies and galaxies + KNe or SNe of several types and within 2 weeks (plus/minus) of max light. In this notebook the classifier assumes we can work in the host rest frame.
#
# Required software:
# * TensorFlow2
# * [desihub software](https://desi.lbl.gov/trac/wiki/Pipeline/GettingStarted/Laptop) (with usual dependencies).
#
# Adding more spectral categories is straightforward.

# %%
from desispec.io import read_spectra
from desitrip.preproc import rebin_flux, rescale_flux

from glob import glob

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow
from joblib import Parallel, delayed

from astropy.table import Table

import os
import shutil
import platform

import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from keras.callbacks import Callback, ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.metrics import confusion_matrix

mpl.rc('font', size=14)

# %% [markdown]
# ## Input Spectra
#
# Input DESI spectra, rebin and rescale them, and then divide them into training and test sets for the classifier.

# %%
def condition_spectra(coadd_files, truth_files):
    """Read DESI spectra, rebin to a subsampled logarithmic wavelength grid, and rescale.
    
    Parameters
    ----------
    coadd_files : list or ndarray
        List of FITS files on disk with DESI spectra.
    truth_files : list or ndarray
        Truth files.
    
    Returns
    -------
    fluxes : ndarray
        Array of fluxes rebinned to a logarithmic wavelength grid.
    """
    fluxes = None
    
    for cf, tf in zip(coadd_files, truth_files):
        spectra = read_spectra(cf)
        wave = spectra.wave['brz']
        flux = spectra.flux['brz']
        ivar = spectra.ivar['brz']
        
        truth = Table.read(tf, 'TRUTH')
        try:
            truez = truth['TRUEZ']
        except:
            print(truth)
            print(cf, tf)

#         # Pre-condition: remove spectra with NaNs and zero flux values.
#         mask = np.isnan(flux).any(axis=1) | (np.count_nonzero(flux, axis=1) == 0)
#         mask_idx = np.argwhere(mask)
#         flux = np.delete(flux, mask_idx, axis=0)
#         ivar = np.delete(ivar, mask_idx, axis=0)

        # Rebin and rescale fluxes so that each is normalized between 0 and 1.
        rewave, reflux, reivar = rebin_flux(wave, flux, ivar, truez, minwave=2500., maxwave=9500., nbins=150, log=True, clip=True)
        rsflux = rescale_flux(reflux)

        # np.ones(shape)
        if fluxes is None:
            fluxes = rsflux
        else:
            fluxes = np.concatenate((fluxes, rsflux))
    
    return fluxes

# %%
path_to_bgs = '/global/cfs/cdirs/desi/science/td/sim/bgs'

# %%
galaxy_truth = sorted(glob('{}/150s/hosts/*truth.fits'.format(path_to_bgs)))
galaxy_coadd = sorted(glob('{}/150s/hosts/*coadd.fits'.format(path_to_bgs)))
galaxy_flux  = condition_spectra(galaxy_coadd, galaxy_truth)
# this cell takes approximately 1min23sec

# %%
snia_truth = sorted(glob('{}/150s/sn_ia/hsiao/*truth.fits'.format(path_to_bgs)))
snia_files = sorted(glob('{}/150s/sn_ia/hsiao/*coadd.fits'.format(path_to_bgs)))
snia_flux  = condition_spectra(snia_files, snia_truth)

# %%
sniip_truth = sorted(glob('{}/150s/sn_iip/*/*truth.fits'.format(path_to_bgs)))
sniip_files = sorted(glob('{}/150s/sn_iip/*/*coadd.fits'.format(path_to_bgs)))
sniip_flux  = condition_spectra(sniip_files, sniip_truth)

# %%
kn_truth = sorted(glob('{}/180s/kn/*/*/*truth.fits'.format(path_to_bgs)))
kn_files = sorted(glob('{}/180s/kn/*/*/*coadd.fits'.format(path_to_bgs)))

# %%
def condition_parallel(njobs, files, truth):
    all_files = np.array_split(files, njobs)
    all_truth = np.array_split(truth, njobs)
    return Parallel(n_jobs=njobs)(delayed(condition_spectra)(all_files[i], all_truth[j]) for i, j in zip(range(njobs), range(njobs)))

flux = condition_parallel(12, kn_files, kn_truth)

# %%
kn_array = np.array(flux)
fluxes = None

for n in range(12):
    if fluxes is None:
        fluxes = kn_array[1]
    else:
        fluxes = np.concatenate((fluxes, kn_array[n]))
            
kn_flux = fluxes

# %%
ngalaxy, nbins  = galaxy_flux.shape
nsnia, nbins  = snia_flux.shape
nsniip, nbins = sniip_flux.shape
nkn, nbins = kn_flux.shape
ngalaxy, nsnia, nsniip, nkn, nbins
# Out:
# (9969, 9964, 9962, 8947, 150)

# %% [markdown]
# ### Plot Spectra to Check Output

# %%
fig, axes = plt.subplots(2,2, figsize=(14,11), sharex=True, sharey=True)
axes = axes.flatten()

for i in range(0,500):
    
    ax = axes[0]
    ax.plot(galaxy_flux[i], alpha=0.2)

    ax = axes[1]
    ax.plot(snia_flux[i], alpha=0.2)
    
    ax = axes[2]
    ax.plot(sniip_flux[i], alpha=0.2)
    
    ax = axes[3]
    ax.plot(kn_flux[i], alpha=0.3)
    
axes[0].set_title('galaxy spectra')
axes[1].set_title('galaxy + SN Ia spectra')
axes[2].set_title('galaxy + SN IIP spectra')
axes[3].set_title('galaxy + KN spectra')

fig.tight_layout()

# %% [markdown]
# ### Set up Training Sets and Labels
#
# 0. "galaxy" spectra based only on BGS templates
# 0. "snia" spectra based on BGS + SN Ia templates
# 0. "sniip" spectra based on BGS + SN IIP templates
# 0. "kn" spectra based on BGS + KN template

# %%
x = np.concatenate([galaxy_flux, 
                    snia_flux,
                    sniip_flux,
                    kn_flux
                   ]).reshape(-1, nbins, 1)

labels = ['Galaxy',
          'SN Ia',
          'SN IIP',
          'KN']
ntypes = len(labels)

# Convert y-label array to appropriate categorical array

y = to_categorical(
        np.concatenate([np.full(ngalaxy, 0), 
                        np.full(nsnia, 1),
                        np.full(nsniip, 2),
                        np.full(nkn, 3)
                       ]))

# %%
x.shape, y.shape
# Out:
# ((38842, 150, 1), (38842, 4))

# %% [markdown]
# ## CNN Network Setup
#
# Train network with TensorFlow+Keras.

# %%
def network(input_shape, ncat, learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1):
    """Define the CNN structure.
    
    Parameters
    ----------
    input_shape : int
        Shape of the input spectra.
    ncat : int
        Number of categories.
    learning_rate : float
        Learning rate.
    reg : float
        Regularization factor.
    dropout : float
        Dropout rate.
    seed : int
        Seed of initializer.
    
    Returns
    -------
    model : tensorflow.keras.Model
        A model instance of the network.
    """
    X_input = Input(input_shape, name='Input_Spec')

    # First convolutional layer.
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Second convolutional layer.
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Third convolutional layer.
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Fourth convolutional layer.
    with backend.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Flatten to fully connected dense layer.
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l1_l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    # Output layer with sigmoid activation.
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l1_l2(reg),
              activation='softmax',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    
    # Set up optimizer, loss function, and optimization metrics.
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = network((nbins, 1), ncat=y.shape[1], learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1)

# %%
model.summary()
# Out:
# Model: "SNnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Spec (InputLayer)      [(None, 150, 1)]          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 150, 8)            48
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 150, 8)            32
# _________________________________________________________________
# activation_8 (Activation)    (None, 150, 8)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 75, 8)             0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 75, 16)            656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 75, 16)            64
# _________________________________________________________________
# activation_9 (Activation)    (None, 75, 16)            0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 37, 16)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 37, 32)            2592
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 37, 32)            128
# _________________________________________________________________
# activation_10 (Activation)   (None, 37, 32)            0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 18, 32)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 18, 64)            10304
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 18, 64)            256
# _________________________________________________________________
# activation_11 (Activation)   (None, 18, 64)            0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 9, 64)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               147712
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Output_Classes (Dense)       (None, 4)                 1028
# =================================================================
# Total params: 162,820
# Trainable params: 162,580
# Non-trainable params: 240
# _________________________________________________________________

# %%
'''tf.keras.utils.plot_model(model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
    )'''
# Out:
# 'tf.keras.utils.plot_model(model,\n    to_file="model.png",\n    show_shapes=True,\n    show_layer_names=True,\n    rankdir="TB",\n    expand_nested=True,\n    dpi=96,\n    )'

# %% [markdown]
# ## Train and Test
#
# Split the data into training and testing (validation) samples and fit the network weights.

# %%
batch = 65
epoch = 200

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=15)
mc = ModelCheckpoint('b{}_e{}_best_model.h5'.format(batch, epoch), monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
hist = model.fit(x_train, y_train, batch_size=batch, epochs=epoch, validation_data=(x_test, y_test), shuffle=True, verbose=True, callbacks=[es, mc])
# Out:
# Epoch 1/200
# 449/449 [==============================] - ETA: 0s - loss: 13.8236 - accuracy: 0.5362
# Epoch 00001: val_accuracy improved from -inf to 0.59942, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 25ms/step - loss: 13.8236 - accuracy: 0.5362 - val_loss: 5.4142 - val_accuracy: 0.5994
# Epoch 2/200
# 448/449 [============================>.] - ETA: 0s - loss: 3.3768 - accuracy: 0.6946
# Epoch 00002: val_accuracy improved from 0.59942 to 0.72166, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 24ms/step - loss: 3.3763 - accuracy: 0.6947 - val_loss: 2.3963 - val_accuracy: 0.7217
# Epoch 3/200
# 446/449 [============================>.] - ETA: 0s - loss: 1.9470 - accuracy: 0.7295
# Epoch 00003: val_accuracy improved from 0.72166 to 0.74843, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 24ms/step - loss: 1.9457 - accuracy: 0.7292 - val_loss: 1.6858 - val_accuracy: 0.7484
# Epoch 4/200
# 448/449 [============================>.] - ETA: 0s - loss: 1.4992 - accuracy: 0.7486
# Epoch 00004: val_accuracy did not improve from 0.74843
# 449/449 [==============================] - 9s 20ms/step - loss: 1.4992 - accuracy: 0.7485 - val_loss: 1.4402 - val_accuracy: 0.7357
# Epoch 5/200
# 446/449 [============================>.] - ETA: 0s - loss: 1.2883 - accuracy: 0.7635
# Epoch 00005: val_accuracy improved from 0.74843 to 0.75687, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 9s 21ms/step - loss: 1.2880 - accuracy: 0.7637 - val_loss: 1.2622 - val_accuracy: 0.7569
# Epoch 6/200
# 447/449 [============================>.] - ETA: 0s - loss: 1.1744 - accuracy: 0.7739
# Epoch 00006: val_accuracy improved from 0.75687 to 0.76511, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 1.1743 - accuracy: 0.7739 - val_loss: 1.1719 - val_accuracy: 0.7651
# Epoch 7/200
# 449/449 [==============================] - ETA: 0s - loss: 1.0949 - accuracy: 0.7826
# Epoch 00007: val_accuracy did not improve from 0.76511
# 449/449 [==============================] - 10s 22ms/step - loss: 1.0949 - accuracy: 0.7826 - val_loss: 1.1607 - val_accuracy: 0.7354
# Epoch 8/200
# 448/449 [============================>.] - ETA: 0s - loss: 1.0413 - accuracy: 0.7880
# Epoch 00008: val_accuracy improved from 0.76511 to 0.78406, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 1.0412 - accuracy: 0.7881 - val_loss: 1.0313 - val_accuracy: 0.7841
# Epoch 9/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.9958 - accuracy: 0.7939
# Epoch 00009: val_accuracy improved from 0.78406 to 0.79868, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.9964 - accuracy: 0.7937 - val_loss: 0.9832 - val_accuracy: 0.7987
# Epoch 10/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.9646 - accuracy: 0.7974 ETA: 0s - loss: 0.965
# Epoch 00010: val_accuracy improved from 0.79868 to 0.80661, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.9647 - accuracy: 0.7975 - val_loss: 0.9438 - val_accuracy: 0.8066
# Epoch 11/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.9336 - accuracy: 0.8020
# Epoch 00011: val_accuracy did not improve from 0.80661
# 449/449 [==============================] - 10s 22ms/step - loss: 0.9336 - accuracy: 0.8019 - val_loss: 0.9500 - val_accuracy: 0.7914
# Epoch 12/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.9099 - accuracy: 0.8056
# Epoch 00012: val_accuracy improved from 0.80661 to 0.81176, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.9099 - accuracy: 0.8056 - val_loss: 0.9055 - val_accuracy: 0.8118
# Epoch 13/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.8944 - accuracy: 0.8066
# Epoch 00013: val_accuracy did not improve from 0.81176
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8943 - accuracy: 0.8066 - val_loss: 0.8927 - val_accuracy: 0.8048
# Epoch 14/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.8755 - accuracy: 0.8088
# Epoch 00014: val_accuracy did not improve from 0.81176
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8756 - accuracy: 0.8088 - val_loss: 0.8863 - val_accuracy: 0.7985
# Epoch 15/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.8612 - accuracy: 0.8112
# Epoch 00015: val_accuracy did not improve from 0.81176
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8611 - accuracy: 0.8114 - val_loss: 0.9198 - val_accuracy: 0.7789
# Epoch 16/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.8501 - accuracy: 0.8119
# Epoch 00016: val_accuracy did not improve from 0.81176
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8503 - accuracy: 0.8118 - val_loss: 0.8709 - val_accuracy: 0.7975
# Epoch 17/200
# 449/449 [==============================] - ETA: 0s - loss: 0.8425 - accuracy: 0.8110
# Epoch 00017: val_accuracy did not improve from 0.81176
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8425 - accuracy: 0.8110 - val_loss: 0.8601 - val_accuracy: 0.8053
# Epoch 18/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.8306 - accuracy: 0.8147
# Epoch 00018: val_accuracy improved from 0.81176 to 0.81536, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8306 - accuracy: 0.8148 - val_loss: 0.8260 - val_accuracy: 0.8154
# Epoch 19/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.8171 - accuracy: 0.8169
# Epoch 00019: val_accuracy improved from 0.81536 to 0.81557, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.8172 - accuracy: 0.8167 - val_loss: 0.8192 - val_accuracy: 0.8156
# Epoch 20/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.8128 - accuracy: 0.8134
# Epoch 00020: val_accuracy did not improve from 0.81557
# 449/449 [==============================] - 10s 23ms/step - loss: 0.8124 - accuracy: 0.8135 - val_loss: 0.8613 - val_accuracy: 0.7868
# Epoch 21/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.8021 - accuracy: 0.8177
# Epoch 00021: val_accuracy improved from 0.81557 to 0.81691, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.8021 - accuracy: 0.8178 - val_loss: 0.8119 - val_accuracy: 0.8169
# Epoch 22/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7968 - accuracy: 0.8178
# Epoch 00022: val_accuracy did not improve from 0.81691
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7974 - accuracy: 0.8176 - val_loss: 0.8237 - val_accuracy: 0.8068
# Epoch 23/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7933 - accuracy: 0.8170
# Epoch 00023: val_accuracy did not improve from 0.81691
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7928 - accuracy: 0.8172 - val_loss: 0.8103 - val_accuracy: 0.8079
# Epoch 24/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7843 - accuracy: 0.8200
# Epoch 00024: val_accuracy improved from 0.81691 to 0.81948, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7843 - accuracy: 0.8199 - val_loss: 0.7916 - val_accuracy: 0.8195
# Epoch 25/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7795 - accuracy: 0.8206
# Epoch 00025: val_accuracy did not improve from 0.81948
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7795 - accuracy: 0.8206 - val_loss: 0.7940 - val_accuracy: 0.8156
# Epoch 26/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7732 - accuracy: 0.8216
# Epoch 00026: val_accuracy improved from 0.81948 to 0.82195, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7734 - accuracy: 0.8215 - val_loss: 0.7863 - val_accuracy: 0.8220
# Epoch 27/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7708 - accuracy: 0.8211
# Epoch 00027: val_accuracy improved from 0.82195 to 0.82226, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7707 - accuracy: 0.8211 - val_loss: 0.7700 - val_accuracy: 0.8223
# Epoch 28/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7639 - accuracy: 0.8243
# Epoch 00028: val_accuracy did not improve from 0.82226
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7639 - accuracy: 0.8243 - val_loss: 0.7984 - val_accuracy: 0.8038
# Epoch 29/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7597 - accuracy: 0.8241
# Epoch 00029: val_accuracy did not improve from 0.82226
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7597 - accuracy: 0.8241 - val_loss: 0.7790 - val_accuracy: 0.8153
# Epoch 30/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7589 - accuracy: 0.8209
# Epoch 00030: val_accuracy did not improve from 0.82226
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7591 - accuracy: 0.8209 - val_loss: 0.7665 - val_accuracy: 0.8196
# Epoch 31/200
# 449/449 [==============================] - ETA: 0s - loss: 0.7507 - accuracy: 0.8254
# Epoch 00031: val_accuracy did not improve from 0.82226
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7507 - accuracy: 0.8254 - val_loss: 0.8104 - val_accuracy: 0.7985
# Epoch 32/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7475 - accuracy: 0.8253
# Epoch 00032: val_accuracy did not improve from 0.82226
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7475 - accuracy: 0.8253 - val_loss: 0.8070 - val_accuracy: 0.7990
# Epoch 33/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7447 - accuracy: 0.8237
# Epoch 00033: val_accuracy improved from 0.82226 to 0.82371, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7448 - accuracy: 0.8237 - val_loss: 0.7471 - val_accuracy: 0.8237
# Epoch 34/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7398 - accuracy: 0.8275
# Epoch 00034: val_accuracy did not improve from 0.82371
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7397 - accuracy: 0.8276 - val_loss: 0.7657 - val_accuracy: 0.8200
# Epoch 35/200
# 449/449 [==============================] - ETA: 0s - loss: 0.7386 - accuracy: 0.8271
# Epoch 00035: val_accuracy did not improve from 0.82371
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7386 - accuracy: 0.8271 - val_loss: 0.7642 - val_accuracy: 0.8160
# Epoch 36/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7346 - accuracy: 0.8268
# Epoch 00036: val_accuracy did not improve from 0.82371
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7348 - accuracy: 0.8268 - val_loss: 0.7547 - val_accuracy: 0.8233
# Epoch 37/200
# 449/449 [==============================] - ETA: 0s - loss: 0.7363 - accuracy: 0.8258
# Epoch 00037: val_accuracy did not improve from 0.82371
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7363 - accuracy: 0.8258 - val_loss: 0.7629 - val_accuracy: 0.8155
# Epoch 38/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7276 - accuracy: 0.8287
# Epoch 00038: val_accuracy did not improve from 0.82371
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7276 - accuracy: 0.8288 - val_loss: 0.8027 - val_accuracy: 0.7935
# Epoch 39/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7254 - accuracy: 0.8302
# Epoch 00039: val_accuracy improved from 0.82371 to 0.82721, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7255 - accuracy: 0.8301 - val_loss: 0.7374 - val_accuracy: 0.8272
# Epoch 40/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7246 - accuracy: 0.8299
# Epoch 00040: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7247 - accuracy: 0.8299 - val_loss: 0.7473 - val_accuracy: 0.8207
# Epoch 41/200
# 449/449 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.8320
# Epoch 00041: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7208 - accuracy: 0.8320 - val_loss: 0.7616 - val_accuracy: 0.8112
# Epoch 42/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7163 - accuracy: 0.8303
# Epoch 00042: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7163 - accuracy: 0.8303 - val_loss: 0.7437 - val_accuracy: 0.8228
# Epoch 43/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7164 - accuracy: 0.8337
# Epoch 00043: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7163 - accuracy: 0.8338 - val_loss: 0.7457 - val_accuracy: 0.8175
# Epoch 44/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.8344
# Epoch 00044: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 11s 24ms/step - loss: 0.7099 - accuracy: 0.8344 - val_loss: 0.7438 - val_accuracy: 0.8225
# Epoch 45/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7100 - accuracy: 0.8347
# Epoch 00045: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7099 - accuracy: 0.8347 - val_loss: 0.7419 - val_accuracy: 0.8233
# Epoch 46/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.8331
# Epoch 00046: val_accuracy did not improve from 0.82721
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7096 - accuracy: 0.8331 - val_loss: 0.7545 - val_accuracy: 0.8076
# Epoch 47/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.8320
# Epoch 00047: val_accuracy improved from 0.82721 to 0.82813, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7060 - accuracy: 0.8320 - val_loss: 0.7149 - val_accuracy: 0.8281
# Epoch 48/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7056 - accuracy: 0.8322
# Epoch 00048: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7055 - accuracy: 0.8323 - val_loss: 0.7267 - val_accuracy: 0.8236
# Epoch 49/200
# 449/449 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.8301
# Epoch 00049: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7075 - accuracy: 0.8301 - val_loss: 0.7306 - val_accuracy: 0.8266
# Epoch 50/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.7006 - accuracy: 0.8336
# Epoch 00050: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 23ms/step - loss: 0.7005 - accuracy: 0.8337 - val_loss: 0.7284 - val_accuracy: 0.8251
# Epoch 51/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.7006 - accuracy: 0.8334
# Epoch 00051: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 22ms/step - loss: 0.7003 - accuracy: 0.8335 - val_loss: 0.7382 - val_accuracy: 0.8168
# Epoch 52/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6961 - accuracy: 0.8330
# Epoch 00052: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6965 - accuracy: 0.8329 - val_loss: 0.7292 - val_accuracy: 0.8194
# Epoch 53/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.8359
# Epoch 00053: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6965 - accuracy: 0.8359 - val_loss: 0.7168 - val_accuracy: 0.8265
# Epoch 54/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6933 - accuracy: 0.8346
# Epoch 00054: val_accuracy did not improve from 0.82813
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6934 - accuracy: 0.8346 - val_loss: 0.7160 - val_accuracy: 0.8248
# Epoch 55/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6915 - accuracy: 0.8360
# Epoch 00055: val_accuracy improved from 0.82813 to 0.82865, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6915 - accuracy: 0.8359 - val_loss: 0.7153 - val_accuracy: 0.8286
# Epoch 56/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6902 - accuracy: 0.8360
# Epoch 00056: val_accuracy did not improve from 0.82865
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6906 - accuracy: 0.8357 - val_loss: 0.7365 - val_accuracy: 0.8173
# Epoch 57/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6896 - accuracy: 0.8358
# Epoch 00057: val_accuracy improved from 0.82865 to 0.83400, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6895 - accuracy: 0.8357 - val_loss: 0.7052 - val_accuracy: 0.8340
# Epoch 58/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6875 - accuracy: 0.8376
# Epoch 00058: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6876 - accuracy: 0.8375 - val_loss: 0.7172 - val_accuracy: 0.8236
# Epoch 59/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6841 - accuracy: 0.8396
# Epoch 00059: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6843 - accuracy: 0.8395 - val_loss: 0.8022 - val_accuracy: 0.7943
# Epoch 60/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6867 - accuracy: 0.8371
# Epoch 00060: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 21ms/step - loss: 0.6868 - accuracy: 0.8369 - val_loss: 0.7441 - val_accuracy: 0.8159
# Epoch 61/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6830 - accuracy: 0.8384
# Epoch 00061: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6830 - accuracy: 0.8384 - val_loss: 0.7060 - val_accuracy: 0.8266
# Epoch 62/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6826 - accuracy: 0.8370
# Epoch 00062: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6825 - accuracy: 0.8370 - val_loss: 0.7295 - val_accuracy: 0.8157
# Epoch 63/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6815 - accuracy: 0.8376
# Epoch 00063: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6815 - accuracy: 0.8375 - val_loss: 0.7223 - val_accuracy: 0.8221
# Epoch 64/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6785 - accuracy: 0.8410 ETA: 0s - loss: 0.6788 - ac
# Epoch 00064: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6787 - accuracy: 0.8409 - val_loss: 0.7084 - val_accuracy: 0.8265
# Epoch 65/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6763 - accuracy: 0.8400
# Epoch 00065: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6767 - accuracy: 0.8398 - val_loss: 0.7292 - val_accuracy: 0.8211
# Epoch 66/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6782 - accuracy: 0.8405
# Epoch 00066: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6783 - accuracy: 0.8404 - val_loss: 0.7078 - val_accuracy: 0.8308
# Epoch 67/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6779 - accuracy: 0.8392
# Epoch 00067: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6779 - accuracy: 0.8392 - val_loss: 0.7818 - val_accuracy: 0.7925
# Epoch 68/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6745 - accuracy: 0.8409
# Epoch 00068: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6745 - accuracy: 0.8410 - val_loss: 0.7124 - val_accuracy: 0.8282
# Epoch 69/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6731 - accuracy: 0.8405
# Epoch 00069: val_accuracy did not improve from 0.83400
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6731 - accuracy: 0.8406 - val_loss: 0.7010 - val_accuracy: 0.8333
# Epoch 70/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6721 - accuracy: 0.8416
# Epoch 00070: val_accuracy improved from 0.83400 to 0.83565, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6720 - accuracy: 0.8416 - val_loss: 0.6897 - val_accuracy: 0.8357
# Epoch 71/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6735 - accuracy: 0.8424
# Epoch 00071: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6737 - accuracy: 0.8423 - val_loss: 0.7054 - val_accuracy: 0.8327
# Epoch 72/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6723 - accuracy: 0.8413
# Epoch 00072: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6723 - accuracy: 0.8413 - val_loss: 0.8375 - val_accuracy: 0.7690
# Epoch 73/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.8408
# Epoch 00073: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6707 - accuracy: 0.8408 - val_loss: 0.7275 - val_accuracy: 0.8234
# Epoch 74/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6658 - accuracy: 0.8419
# Epoch 00074: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6662 - accuracy: 0.8418 - val_loss: 0.7706 - val_accuracy: 0.8006
# Epoch 75/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6690 - accuracy: 0.8430
# Epoch 00075: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6691 - accuracy: 0.8430 - val_loss: 0.7059 - val_accuracy: 0.8298
# Epoch 76/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6693 - accuracy: 0.8409
# Epoch 00076: val_accuracy did not improve from 0.83565
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6693 - accuracy: 0.8409 - val_loss: 0.6914 - val_accuracy: 0.8339
# Epoch 77/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6674 - accuracy: 0.8402
# Epoch 00077: val_accuracy improved from 0.83565 to 0.83730, saving model to b65_e200_best_model.h5
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6674 - accuracy: 0.8402 - val_loss: 0.6965 - val_accuracy: 0.8373
# Epoch 78/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6622 - accuracy: 0.8440
# Epoch 00078: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6622 - accuracy: 0.8440 - val_loss: 0.6959 - val_accuracy: 0.8329
# Epoch 79/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6677 - accuracy: 0.8427
# Epoch 00079: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 11s 24ms/step - loss: 0.6677 - accuracy: 0.8427 - val_loss: 0.7506 - val_accuracy: 0.8110
# Epoch 80/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6648 - accuracy: 0.8427
# Epoch 00080: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 11s 24ms/step - loss: 0.6648 - accuracy: 0.8427 - val_loss: 0.7445 - val_accuracy: 0.8107
# Epoch 81/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6627 - accuracy: 0.8420
# Epoch 00081: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6625 - accuracy: 0.8422 - val_loss: 0.7066 - val_accuracy: 0.8240
# Epoch 82/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6610 - accuracy: 0.8438
# Epoch 00082: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6608 - accuracy: 0.8439 - val_loss: 0.7060 - val_accuracy: 0.8251
# Epoch 83/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6611 - accuracy: 0.8408
# Epoch 00083: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6612 - accuracy: 0.8407 - val_loss: 0.7279 - val_accuracy: 0.8136
# Epoch 84/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6589 - accuracy: 0.8449
# Epoch 00084: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6589 - accuracy: 0.8449 - val_loss: 0.6933 - val_accuracy: 0.8333
# Epoch 85/200
# 449/449 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.8445
# Epoch 00085: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 23ms/step - loss: 0.6596 - accuracy: 0.8445 - val_loss: 0.7449 - val_accuracy: 0.7971
# Epoch 86/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6602 - accuracy: 0.8418
# Epoch 00086: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6602 - accuracy: 0.8418 - val_loss: 0.7155 - val_accuracy: 0.8142
# Epoch 87/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6585 - accuracy: 0.8415
# Epoch 00087: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6585 - accuracy: 0.8415 - val_loss: 0.7291 - val_accuracy: 0.8179
# Epoch 88/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6597 - accuracy: 0.8430
# Epoch 00088: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6599 - accuracy: 0.8427 - val_loss: 0.7213 - val_accuracy: 0.8118
# Epoch 89/200
# 446/449 [============================>.] - ETA: 0s - loss: 0.6596 - accuracy: 0.8423
# Epoch 00089: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 10s 22ms/step - loss: 0.6595 - accuracy: 0.8423 - val_loss: 0.7050 - val_accuracy: 0.8251
# Epoch 90/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6586 - accuracy: 0.8430
# Epoch 00090: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 9s 20ms/step - loss: 0.6585 - accuracy: 0.8430 - val_loss: 0.6820 - val_accuracy: 0.8325
# Epoch 91/200
# 447/449 [============================>.] - ETA: 0s - loss: 0.6539 - accuracy: 0.8442
# Epoch 00091: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 9s 21ms/step - loss: 0.6536 - accuracy: 0.8444 - val_loss: 0.6918 - val_accuracy: 0.8289
# Epoch 92/200
# 448/449 [============================>.] - ETA: 0s - loss: 0.6549 - accuracy: 0.8420
# Epoch 00092: val_accuracy did not improve from 0.83730
# 449/449 [==============================] - 9s 21ms/step - loss: 0.6548 - accuracy: 0.8420 - val_loss: 0.7253 - val_accuracy: 0.8207
# Epoch 00092: early stopping

# %% [markdown]
# ## Performance
#
# ### Loss and Accuracy
#
# Plot loss and accuracy as a function of epoch.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5), sharex=True)

nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, hist.history['accuracy'], label='acc')
ax.plot(epochs, hist.history['val_accuracy'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.,1.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
#        ylim=(0.,2.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

fig.tight_layout()
plt.savefig('b{}_e{}_accuracy.png'.format(batch, epoch))

# %% [markdown]
# ### ROC Curve and Precision-Recall
#
# Plot both the ROC curves per class and the class-averaged ROC curve.

# %%
y_pred = model.predict(x_test)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])
    
    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')
    
    pre[i], rec[i], _ = precision_recall_curve(y_test[:,i], y_pred[:,i])
    
    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])
        
ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_test.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_test, y_pred)),
       aspect='equal')

fig.tight_layout()
plt.savefig('b{}_e{}_metrics.png'.format(batch, epoch))

# %% [markdown]
# ### Confusion Matrix

# %%
# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')

fig.tight_layout()
plt.savefig('b{}_e{}_matrix.png'.format(batch, epoch))

# %%
model.save('b{}_e{}_3label_model'.format(batch, epoch))
# Out:
# INFO:tensorflow:Assets written to: b65_e200_3label_model/assets

# %%
model.save('b{}_e{}_3label.h5'.format(batch, epoch))

# %%
nb_path = '/global/u1/l/lehsani/timedomain/desitrip/docs/nb'

if not '1_b{}_e{}_3label'.format(batch, epoch) in os.listdir(nb_path):
    os.mkdir('1_b{}_e{}_3label'.format(batch, epoch))
    num = 1
else:
    folders = []
    for file in os.listdir(nb_path):
        if file.endswith('b{}_e{}_3label'.format(batch, epoch)):
            folders.append(file)
        else:
            continue
    folders = sorted(folders)
    num = folders[-1].split('_')[0]
    num = int(num) + 1
    os.mkdir('{}_b{}_e{}_3label'.format(num, batch, epoch))

for file in os.listdir(nb_path):
    if file == 'b{}_e{}_3label'.format(batch, epoch):
        continue
    if file.startswith('b{}_e{}'.format(batch, epoch)):
        shutil.move('{}/{}'.format(nb_path, file), '{}/{}_b{}_e{}_3label/{}'.format(nb_path, num, batch, epoch, file))
