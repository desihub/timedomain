# %% [markdown]
# # CNN Classifier Training Example
#
# This notebook demonstrates a basic 4-layer CNN trained to classify spectra from galaxies and galaxies + SNe of several types within 2 weeks (plus/minus) of max light. In this notebook the classifier assumes we can work in the host rest frame.
#
# Required software:
# * TensorFlow2
# * [desihub software](https://desi.lbl.gov/trac/wiki/Pipeline/GettingStarted/Laptop) (with usual dependencies).
#
# Adding more spectral categories is straightforward.

# %%
from desispec.io import read_spectra
from desitrip.preproc import rebin_flux, rescale_flux

from glob import glob

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow
from joblib import Parallel, delayed

from astropy.table import Table

import os
import platform

mpl.rc('font', size=14)

# %% [markdown]
# ## Input Spectra
#
# Input DESI spectra, rebin and rescale them, and then divide them into training and test sets for the classifier.

# %%
def condition_spectra(coadd_files, truth_files):
    """Read DESI spectra, rebin to a subsampled logarithmic wavelength grid, and rescale.
    
    Parameters
    ----------
    coadd_files : list or ndarray
        List of FITS files on disk with DESI spectra.
    truth_files : list or ndarray
        Truth files.
    
    Returns
    -------
    fluxes : ndarray
        Array of fluxes rebinned to a logarithmic wavelength grid.
    """
    fluxes = None
    
    for cf, tf in zip(coadd_files, truth_files):
        spectra = read_spectra(cf)
        wave = spectra.wave['brz']
        flux = spectra.flux['brz']
        ivar = spectra.ivar['brz']
        
        truth = Table.read(tf, 'TRUTH')
        try:
            truez = truth['TRUEZ']
        except:
            print(truth)
            print(cf, tf)

#         # Pre-condition: remove spectra with NaNs and zero flux values.
#         mask = np.isnan(flux).any(axis=1) | (np.count_nonzero(flux, axis=1) == 0)
#         mask_idx = np.argwhere(mask)
#         flux = np.delete(flux, mask_idx, axis=0)
#         ivar = np.delete(ivar, mask_idx, axis=0)

        # Rebin and rescale fluxes so that each is normalized between 0 and 1.
        rewave, reflux, reivar = rebin_flux(wave, flux, ivar, truez, minwave=2500., maxwave=9500., nbins=150, log=True, clip=True)
        rsflux = rescale_flux(reflux)

        if fluxes is None:
            fluxes = rsflux
        else:
            fluxes = np.concatenate((fluxes, rsflux))
    
    return fluxes

# %%
path_to_bgs = '/global/cfs/cdirs/desi/science/td/sim/bgs'

# %%
host_truth = sorted(glob('{}/150s/hosts/*truth.fits'.format(path_to_bgs)))
host_coadd = sorted(glob('{}/150s/hosts/*coadd.fits'.format(path_to_bgs)))
host_flux  = condition_spectra(host_coadd, host_truth)
# this cell takes approximately 1min23sec

# %%
snia_truth = sorted(glob('{}/150s/sn_ia/hsiao/*truth.fits'.format(path_to_bgs)))
snia_files = sorted(glob('{}/150s/sn_ia/hsiao/*coadd.fits'.format(path_to_bgs)))
snia_flux  = condition_spectra(snia_files, snia_truth)

# %%
sniip_truth = sorted(glob('{}/150s/sn_iip/*/*truth.fits'.format(path_to_bgs)))
sniip_files = sorted(glob('{}/150s/sn_iip/*/*coadd.fits'.format(path_to_bgs)))
sniip_flux  = condition_spectra(sniip_files, sniip_truth)

# %%
kn_truth = sorted(glob('{}/180s/kn/*/*/*truth.fits'.format(path_to_bgs)))
kn_files = sorted(glob('{}/180s/kn/*/*/*coadd.fits'.format(path_to_bgs)))

# %%
def condition_parallel(njobs, files, truth):
    all_files = np.array_split(files, njobs)
    all_truth = np.array_split(truth, njobs)
    return Parallel(n_jobs=njobs)(delayed(condition_spectra)(all_files[i], all_truth[j]) for i, j in zip(range(njobs), range(njobs)))

flux = condition_parallel(12, kn_files, kn_truth)
# Out:
# 12

# %%
kn_array = np.array(flux)
fluxes = None

for n in range(12):
    if fluxes is None:
        fluxes = kn_array[1]
    else:
        fluxes = np.concatenate((fluxes, kn_array[n]))
            
kn_flux = fluxes

# %%
print('kn_truth len: {}'.format((len(kn_truth))))
print('snia_truth len: {}'.format(len(snia_truth)))
print('kn_files len: {}'.format(len(kn_files)))
print('snia_files len: {}'.format(len(snia_files)))
print('kn_flux len: {}'.format(len(kn_flux)))
print('snia_flux len: {}'.format(len(snia_flux)))
# Out:
# kn_truth len: 12047
# snia_truth len: 100
# kn_files len: 12047
# snia_files len: 100
# kn_flux len: 12010
# snia_flux len: 9964

# %%
nhost, nbins  = host_flux.shape
nsnia, nbins  = snia_flux.shape
nsniip, nbins = sniip_flux.shape
nkn, nbins = kn_flux.shape
nhost, nsnia, nsniip, nkn, nbins
# Out:
# (9969, 9964, 9962, 12010, 150)

# %% [markdown]
# ### Plot Spectra to Check Output

# %%
fig, axes = plt.subplots(2,2, figsize=(14,11), sharex=True, sharey=True)
axes = axes.flatten()

for i in range(0,500):
    
    ax = axes[0]
    ax.plot(host_flux[i], alpha=0.2)

    ax = axes[1]
    ax.plot(snia_flux[i], alpha=0.2)
    
    ax = axes[2]
    ax.plot(sniip_flux[i], alpha=0.2)
    
    ax = axes[3]
    ax.plot(kn_flux[i], alpha=0.3)
    
axes[0].set_title('host spectra')
axes[1].set_title('host + SN Ia spectra')
axes[2].set_title('host + SN IIP spectra')
axes[3].set_title('host + KN spectra')

fig.tight_layout()

# %% [markdown]
# ### Set up Training Sets and Labels
#
# 0. "host" spectra based only on BGS templates
# 0. "snia" spectra based on BGS + SN Ia templates
# 0. "sniip" spectra based on BGS + SN IIP templates
# 0. "kn" spectra based on BGS + KN template

# %%
x = np.concatenate([host_flux, 
                    snia_flux,
                    sniip_flux,
                    kn_flux
                   ]).reshape(-1, nbins, 1)

labels = ['Host',
          'SN Ia',
          'SN IIP',
          'KN']
ntypes = len(labels)

# Convert y-label array to appropriate categorical array
from tensorflow.keras.utils import to_categorical

y = to_categorical(
        np.concatenate([np.full(nhost, 0), 
                        np.full(nsnia, 1),
                        np.full(nsniip, 2),
                        np.full(nkn, 3)
                       ]))

# %%
x.shape, y.shape
# Out:
# ((41903, 150, 1), (41903, 4))

# %% [markdown]
# ## CNN Network Setup
#
# Train network with TensorFlow+Keras.

# %%
import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

import pydot
import graphviz

# %%
def network(input_shape, ncat, learning_rate=0.0005, reg=0.0032, dropout=0.7436, seed=None):
    """Define the CNN structure.
    
    Parameters
    ----------
    input_shape : int
        Shape of the input spectra.
    ncat : int
        Number of categories.
    learning_rate : float
        Learning rate.
    reg : float
        Regularization factor.
    dropout : float
        Dropout rate.
    seed : int
        Seed of initializer.
    
    Returns
    -------
    model : tensorflow.keras.Model
        A model instance of the network.
    """
    X_input = Input(input_shape, name='Input_Spec')

    # First convolutional layer.
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Second convolutional layer.
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Third convolutional layer.
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Fourth convolutional layer.
    with backend.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l2(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Flatten to fully connected dense layer.
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    # Output layer with sigmoid activation.
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l2(reg),
              activation='sigmoid',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    
    # Set up optimizer, loss function, and optimization metrics.
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = network((nbins, 1), ncat=y.shape[1])

# %%
model.summary()
# Out:
# Model: "SNnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Spec (InputLayer)      [(None, 150, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 150, 8)            48
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 8)            32
# _________________________________________________________________
# activation (Activation)      (None, 150, 8)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 75, 8)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 75, 16)            656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 16)            64
# _________________________________________________________________
# activation_1 (Activation)    (None, 75, 16)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 37, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 37, 32)            2592
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 37, 32)            128
# _________________________________________________________________
# activation_2 (Activation)    (None, 37, 32)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 18, 32)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 18, 64)            10304
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 18, 64)            256
# _________________________________________________________________
# activation_3 (Activation)    (None, 18, 64)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 9, 64)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               147712
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output_Classes (Dense)       (None, 4)                 1028
# =================================================================
# Total params: 162,820
# Trainable params: 162,580
# Non-trainable params: 240
# _________________________________________________________________

# %%
'''tf.keras.utils.plot_model(model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
    )'''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pydot.py in create(self, prog, format)
#    1877                 shell=False,
# -> 1878                 stderr=subprocess.PIPE, stdout=subprocess.PIPE)
#    1879         except OSError as e:
#
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1343                             err_msg += ': ' + repr(err_filename)
# -> 1344                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1345                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-f0270045fdf2> in <module>
#       5     rankdir="TB",
#       6     expand_nested=True,
# ----> 7     dpi=96,
#       8     )
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     304                      rankdir=rankdir,
#     305                      expand_nested=expand_nested,
# --> 306                      dpi=dpi)
#     307   to_file = path_to_string(to_file)
#     308   if dot is None:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#     101   from tensorflow.python.keras.engine import functional
#     102
# --> 103   if not check_pydot():
#     104     message = (
#     105         'Failed to import pydot. You must `pip install pydot` '
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/vis_utils.py in check_pydot()
#      49     # Attempt to create an image of a blank graph
#      50     # to check the pydot/graphviz installation.
# ---> 51     pydot.Dot.create(pydot.Dot())
#      52     return True
#      53   except (OSError, pydot.InvocationException):
#
# ~/.local/lib/python3.6/site-packages/pydot.py in create(self, prog, format)
#    1881                 raise Exception(
#    1882                     '"{prog}" not found in path.'.format(
# -> 1883                         prog=prog))
#    1884             else:
#    1885                 raise
#
# Exception: "dot" not found in path.

# %% [markdown]
# ## Train and Test
#
# Split the data into training and testing (validation) samples and fit the network weights.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
hist = model.fit(x_train, y_train, batch_size=65, epochs=50, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Epoch 1/50
# 484/484 [==============================] - 10s 20ms/step - loss: 1.2397 - accuracy: 0.6266 - val_loss: 1.0733 - val_accuracy: 0.6586
# Epoch 2/50
# 484/484 [==============================] - 12s 24ms/step - loss: 1.0471 - accuracy: 0.6590 - val_loss: 0.9917 - val_accuracy: 0.6684
# Epoch 3/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.9593 - accuracy: 0.6738 - val_loss: 0.9202 - val_accuracy: 0.6882
# Epoch 4/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.9029 - accuracy: 0.6854 - val_loss: 0.8769 - val_accuracy: 0.7010
# Epoch 5/50
# 484/484 [==============================] - 15s 30ms/step - loss: 0.8686 - accuracy: 0.6951 - val_loss: 0.8454 - val_accuracy: 0.6978
# Epoch 6/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.8372 - accuracy: 0.7031 - val_loss: 0.8367 - val_accuracy: 0.6982
# Epoch 7/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.8225 - accuracy: 0.7056 - val_loss: 0.8299 - val_accuracy: 0.6985
# Epoch 8/50
# 484/484 [==============================] - 10s 20ms/step - loss: 0.8039 - accuracy: 0.7152 - val_loss: 0.7781 - val_accuracy: 0.7233
# Epoch 9/50
# 484/484 [==============================] - 10s 20ms/step - loss: 0.7941 - accuracy: 0.7190 - val_loss: 0.7726 - val_accuracy: 0.7215
# Epoch 10/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.7841 - accuracy: 0.7233 - val_loss: 0.7437 - val_accuracy: 0.7399
# Epoch 11/50
# 484/484 [==============================] - 10s 21ms/step - loss: 0.7756 - accuracy: 0.7254 - val_loss: 0.7376 - val_accuracy: 0.7376
# Epoch 12/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.7679 - accuracy: 0.7302 - val_loss: 0.7613 - val_accuracy: 0.7257
# Epoch 13/50
# 484/484 [==============================] - 18s 37ms/step - loss: 0.7576 - accuracy: 0.7309 - val_loss: 0.7404 - val_accuracy: 0.7369
# Epoch 14/50
# 484/484 [==============================] - 12s 25ms/step - loss: 0.7516 - accuracy: 0.7331 - val_loss: 0.7797 - val_accuracy: 0.7105
# Epoch 15/50
# 484/484 [==============================] - 12s 24ms/step - loss: 0.7510 - accuracy: 0.7364 - val_loss: 0.7320 - val_accuracy: 0.7418
# Epoch 16/50
# 484/484 [==============================] - 15s 31ms/step - loss: 0.7423 - accuracy: 0.7403 - val_loss: 0.7212 - val_accuracy: 0.7449
# Epoch 17/50
# 484/484 [==============================] - 14s 28ms/step - loss: 0.7386 - accuracy: 0.7387 - val_loss: 0.7236 - val_accuracy: 0.7414
# Epoch 18/50
# 484/484 [==============================] - 12s 25ms/step - loss: 0.7371 - accuracy: 0.7421 - val_loss: 0.7196 - val_accuracy: 0.7506
# Epoch 19/50
# 484/484 [==============================] - 17s 35ms/step - loss: 0.7299 - accuracy: 0.7459 - val_loss: 0.7254 - val_accuracy: 0.7468
# Epoch 20/50
# 484/484 [==============================] - 14s 29ms/step - loss: 0.7255 - accuracy: 0.7479 - val_loss: 0.7376 - val_accuracy: 0.7422
# Epoch 21/50
# 484/484 [==============================] - 11s 23ms/step - loss: 0.7200 - accuracy: 0.7516 - val_loss: 0.7137 - val_accuracy: 0.7507
# Epoch 22/50
# 484/484 [==============================] - 14s 29ms/step - loss: 0.7204 - accuracy: 0.7527 - val_loss: 0.7219 - val_accuracy: 0.7536
# Epoch 23/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.7153 - accuracy: 0.7546 - val_loss: 0.7040 - val_accuracy: 0.7543
# Epoch 24/50
# 484/484 [==============================] - 17s 34ms/step - loss: 0.7133 - accuracy: 0.7555 - val_loss: 0.7131 - val_accuracy: 0.7549
# Epoch 25/50
# 484/484 [==============================] - 10s 21ms/step - loss: 0.7082 - accuracy: 0.7594 - val_loss: 0.7369 - val_accuracy: 0.7426
# Epoch 26/50
# 484/484 [==============================] - 20s 41ms/step - loss: 0.7062 - accuracy: 0.7601 - val_loss: 0.6779 - val_accuracy: 0.7650
# Epoch 27/50
# 484/484 [==============================] - 22s 45ms/step - loss: 0.7024 - accuracy: 0.7620 - val_loss: 0.7155 - val_accuracy: 0.7436
# Epoch 28/50
# 484/484 [==============================] - 12s 24ms/step - loss: 0.7020 - accuracy: 0.7618 - val_loss: 0.6994 - val_accuracy: 0.7611
# Epoch 29/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.6970 - accuracy: 0.7637 - val_loss: 0.6911 - val_accuracy: 0.7598
# Epoch 30/50
# 484/484 [==============================] - 14s 28ms/step - loss: 0.6968 - accuracy: 0.7655 - val_loss: 0.7066 - val_accuracy: 0.7530
# Epoch 31/50
# 484/484 [==============================] - 12s 25ms/step - loss: 0.6912 - accuracy: 0.7679 - val_loss: 0.7091 - val_accuracy: 0.7510
# Epoch 32/50
# 484/484 [==============================] - 12s 25ms/step - loss: 0.6951 - accuracy: 0.7684 - val_loss: 0.6888 - val_accuracy: 0.7706
# Epoch 33/50
# 484/484 [==============================] - 27s 55ms/step - loss: 0.6903 - accuracy: 0.7693 - val_loss: 0.7455 - val_accuracy: 0.7417
# Epoch 34/50
# 484/484 [==============================] - 16s 34ms/step - loss: 0.6867 - accuracy: 0.7725 - val_loss: 0.7018 - val_accuracy: 0.7573
# Epoch 35/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.6847 - accuracy: 0.7747 - val_loss: 0.6915 - val_accuracy: 0.7672
# Epoch 36/50
# 484/484 [==============================] - 12s 25ms/step - loss: 0.6841 - accuracy: 0.7747 - val_loss: 0.6773 - val_accuracy: 0.7702
# Epoch 37/50
# 484/484 [==============================] - 16s 33ms/step - loss: 0.6798 - accuracy: 0.7779 - val_loss: 0.6669 - val_accuracy: 0.7825
# Epoch 38/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.6806 - accuracy: 0.7771 - val_loss: 0.6865 - val_accuracy: 0.7681
# Epoch 39/50
# 484/484 [==============================] - 16s 34ms/step - loss: 0.6744 - accuracy: 0.7792 - val_loss: 0.7027 - val_accuracy: 0.7637
# Epoch 40/50
# 484/484 [==============================] - 14s 30ms/step - loss: 0.6778 - accuracy: 0.7776 - val_loss: 0.6897 - val_accuracy: 0.7710
# Epoch 41/50
# 484/484 [==============================] - 10s 21ms/step - loss: 0.6738 - accuracy: 0.7819 - val_loss: 0.6797 - val_accuracy: 0.7690
# Epoch 42/50
# 484/484 [==============================] - 10s 21ms/step - loss: 0.6713 - accuracy: 0.7821 - val_loss: 0.7461 - val_accuracy: 0.7438
# Epoch 43/50
# 484/484 [==============================] - 11s 22ms/step - loss: 0.6724 - accuracy: 0.7815 - val_loss: 0.7262 - val_accuracy: 0.7397
# Epoch 44/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.6687 - accuracy: 0.7848 - val_loss: 0.6802 - val_accuracy: 0.7717
# Epoch 45/50
# 484/484 [==============================] - 13s 28ms/step - loss: 0.6650 - accuracy: 0.7883 - val_loss: 0.6635 - val_accuracy: 0.7889
# Epoch 46/50
# 484/484 [==============================] - 13s 27ms/step - loss: 0.6642 - accuracy: 0.7889 - val_loss: 0.6853 - val_accuracy: 0.7804
# Epoch 47/50
# 484/484 [==============================] - 14s 28ms/step - loss: 0.6625 - accuracy: 0.7886 - val_loss: 0.6947 - val_accuracy: 0.7712
# Epoch 48/50
# 484/484 [==============================] - 12s 24ms/step - loss: 0.6621 - accuracy: 0.7886 - val_loss: 0.6768 - val_accuracy: 0.7777
# Epoch 49/50
# 484/484 [==============================] - 15s 30ms/step - loss: 0.6601 - accuracy: 0.7922 - val_loss: 0.7267 - val_accuracy: 0.7532
# Epoch 50/50
# 484/484 [==============================] - 10s 21ms/step - loss: 0.6627 - accuracy: 0.7892 - val_loss: 0.7254 - val_accuracy: 0.7539

# %% [markdown]
# ## Performance
#
# ### Loss and Accuracy
#
# Plot loss and accuracy as a function of epoch.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5), sharex=True)

nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, hist.history['accuracy'], label='acc')
ax.plot(epochs, hist.history['val_accuracy'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.,1.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
#        ylim=(0.,2.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

fig.tight_layout()
plt.savefig('accuracy.png')

# %% [markdown]
# ### ROC Curve and Precision-Recall
#
# Plot both the ROC curves per class and the class-averaged ROC curve.

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])
    
    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')
    
    pre[i], rec[i], _ = precision_recall_curve(y_test[:,i], y_pred[:,i])
    
    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])
        
ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_test.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_test, y_pred)),
       aspect='equal')

fig.tight_layout()
plt.savefig('metrics.png')

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')

fig.tight_layout()
plt.savefig('confusionmatrix.png')

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31427, 150, 1)
# (10476, 150, 1)
# (31427, 4)
# (10476, 4)

# %%
model.save('3label_cnn_restframe')
# Out:
# WARNING:tensorflow:From /global/homes/l/lehsani/.local/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /global/homes/l/lehsani/.local/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: 3label_cnn_restframe/assets

# %%
model.save('3label_cnn_restframe.h5')

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

train = np.sum(y_train)
test = np.sum(y_test)

def count_col(j, arr):
    sum = 0
    for i in range(len(arr)):
        sum += arr[i][j]
    return sum

# %%
print(count_col(0, y_train))
print(count_col(1, y_train))
print(count_col(2, y_train))
print(count_col(3, y_train))
print(count_col(4, y_train))
print(count_col(5, y_train))
print(count_col(6, y_train))
print(count_col(7, y_train))
print(count_col(8, y_train))
# Out:
# 7535.0
# 7450.0
# 7492.0
# 7505.0
# 7470.0
# 7478.0
# 7471.0
# 7486.0
# 8933.0

# %%
print(count_col(0, y_test))
print(count_col(1, y_test))
print(count_col(2, y_test))
print(count_col(3, y_test))
print(count_col(4, y_test))
print(count_col(5, y_test))
print(count_col(6, y_test))
print(count_col(7, y_test))
print(count_col(8, y_test))
# Out:
# 2434.0
# 2519.0
# 2477.0
# 2464.0
# 2499.0
# 2491.0
# 2498.0
# 2483.0
# 3075.0
