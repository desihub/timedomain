# %% [markdown]
# # CNN Classifier Training Example
#
# This notebook demonstrates a basic 4-layer CNN trained to classify spectra from galaxies and galaxies + SNe of several types within 2 weeks (plus/minus) of max light. In this notebook the classifier assumes we can work in the host rest frame.
#
# Required software:
# * TensorFlow2
# * [desihub software](https://desi.lbl.gov/trac/wiki/Pipeline/GettingStarted/Laptop) (with usual dependencies).
#
# Adding more spectral categories is straightforward.

# %%
from desispec.io import read_spectra
from desitrip.preproc import rebin_flux, rescale_flux

from glob import glob

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow
from joblib import Parallel, delayed

from astropy.table import Table

import os
import shutil
import platform

import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from keras.callbacks import Callback, ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.metrics import confusion_matrix

mpl.rc('font', size=14)

# %% [markdown]
# ## Input Spectra
#
# Input DESI spectra, rebin and rescale them, and then divide them into training and test sets for the classifier.

# %%
def condition_spectra(coadd_files, truth_files):
    """Read DESI spectra, rebin to a subsampled logarithmic wavelength grid, and rescale.
    
    Parameters
    ----------
    coadd_files : list or ndarray
        List of FITS files on disk with DESI spectra.
    truth_files : list or ndarray
        Truth files.
    
    Returns
    -------
    fluxes : ndarray
        Array of fluxes rebinned to a logarithmic wavelength grid.
    """
    fluxes = None
    
    for cf, tf in zip(coadd_files, truth_files):
        spectra = read_spectra(cf)
        wave = spectra.wave['brz']
        flux = spectra.flux['brz']
        ivar = spectra.ivar['brz']
        
        truth = Table.read(tf, 'TRUTH')
        try:
            truez = truth['TRUEZ']
        except:
            print(truth)
            print(cf, tf)

#         # Pre-condition: remove spectra with NaNs and zero flux values.
#         mask = np.isnan(flux).any(axis=1) | (np.count_nonzero(flux, axis=1) == 0)
#         mask_idx = np.argwhere(mask)
#         flux = np.delete(flux, mask_idx, axis=0)
#         ivar = np.delete(ivar, mask_idx, axis=0)

        # Rebin and rescale fluxes so that each is normalized between 0 and 1.
        rewave, reflux, reivar = rebin_flux(wave, flux, ivar, truez, minwave=2500., maxwave=9500., nbins=150, log=True, clip=True)
        rsflux = rescale_flux(reflux)

        if fluxes is None:
            fluxes = rsflux
        else:
            fluxes = np.concatenate((fluxes, rsflux))
    
    return fluxes

# %%
path_to_bgs = '/global/cfs/cdirs/desi/science/td/sim/bgs'

# %%
galaxy_truth = sorted(glob('{}/150s/hosts/*truth.fits'.format(path_to_bgs)))
galaxy_coadd = sorted(glob('{}/150s/hosts/*coadd.fits'.format(path_to_bgs)))
galaxy_flux  = condition_spectra(galaxy_coadd, galaxy_truth)

# %%
snia_truth = sorted(glob('{}/150s/sn_ia/hsiao/*truth.fits'.format(path_to_bgs)))
snia_files = sorted(glob('{}/150s/sn_ia/hsiao/*coadd.fits'.format(path_to_bgs)))
snia_flux  = condition_spectra(snia_files, snia_truth)

# %%
snib_truth = sorted(glob('{}/150s/sn_ib/*/*truth.fits'.format(path_to_bgs)))
snib_files = sorted(glob('{}/150s/sn_ib/*/*coadd.fits'.format(path_to_bgs)))
snib_flux  = condition_spectra(snib_files, snib_truth)

# %%
snibc_truth = sorted(glob('{}/150s/sn_ibc/*/*truth.fits'.format(path_to_bgs)))
snibc_files = sorted(glob('{}/150s/sn_ibc/*/*coadd.fits'.format(path_to_bgs)))
snibc_flux  = condition_spectra(snibc_files, snibc_truth)

# %%
snic_truth = sorted(glob('{}/150s/sn_ic/*/*truth.fits'.format(path_to_bgs)))
snic_files = sorted(glob('{}/150s/sn_ic/*/*coadd.fits'.format(path_to_bgs)))
snic_flux  = condition_spectra(snic_files, snic_truth)

# %%
sniin_truth = sorted(glob('{}/150s/sn_iin/*/*truth.fits'.format(path_to_bgs)))
sniin_files = sorted(glob('{}/150s/sn_iin/*/*coadd.fits'.format(path_to_bgs)))
sniin_flux  = condition_spectra(sniin_files, sniin_truth)

# %%
sniilp_truth = sorted(glob('{}/150s/sn_iilp/*/*truth.fits'.format(path_to_bgs)))
sniilp_files = sorted(glob('{}/150s/sn_iilp/*/*coadd.fits'.format(path_to_bgs)))
sniilp_flux  = condition_spectra(sniilp_files, sniilp_truth)

# %%
sniip_truth = sorted(glob('{}/150s/sn_iip/*/*truth.fits'.format(path_to_bgs)))
sniip_files = sorted(glob('{}/150s/sn_iip/*/*coadd.fits'.format(path_to_bgs)))
sniip_flux  = condition_spectra(sniip_files, sniip_truth)

# %%
kn_truth = sorted(glob('{}/180s/kn/*/*/*truth.fits'.format(path_to_bgs)))
kn_files = sorted(glob('{}/180s/kn/*/*/*coadd.fits'.format(path_to_bgs)))

# %%
print('kn_truth len: {}'.format((len(kn_truth))))
print('snia_truth len: {}'.format(len(snia_truth)))
print('kn_files len: {}'.format(len(kn_files)))
print('snia_files len: {}'.format(len(snia_files)))
print('snia_flux len: {}'.format(len(snia_flux)))
# Out:
# kn_truth len: 9415
# snia_truth len: 100
# kn_files len: 8978
# snia_files len: 100
# snia_flux len: 9964

# %%
def condition_parallel(njobs, files, truth):
    all_files = np.array_split(files, njobs)
    all_truth = np.array_split(truth, njobs)
    return Parallel(n_jobs=njobs)(delayed(condition_spectra)(all_files[i], all_truth[j]) for i, j in zip(range(njobs), range(njobs)))

flux = condition_parallel(12, kn_files, kn_truth)

# %%
kn_array = np.array(flux)
fluxes = None

for n in range(12):
    if fluxes is None:
        fluxes = kn_array[1]
    else:
        fluxes = np.concatenate((fluxes, kn_array[n]))
            
kn_flux = fluxes

# %%
ngalaxy, nbins  = galaxy_flux.shape
nsnia, nbins  = snia_flux.shape
nsnib, nbins  = snib_flux.shape
nsnibc, nbins = snibc_flux.shape
nsnic, nbins  = snic_flux.shape
nsniin, nbins = sniin_flux.shape
nsniilp, nbins = sniilp_flux.shape
nsniip, nbins = sniip_flux.shape
nkn, nbins = kn_flux.shape
ngalaxy, nsnia, nsnib, nsnibc, nsnic, nsniin, nsniilp, nsniip, nkn, nbins
# Out:
# (9969, 9964, 9958, 9971, 8269, 9949, 9948, 9962, 8947, 150)

# %% [markdown]
# ### Plot Spectra to Check Output

# %%
fig, axes = plt.subplots(3,3, figsize=(14,11), sharex=True, sharey=True)
axes = axes.flatten()

for i in range(0,500):
    
    ax = axes[0]
    ax.plot(galaxy_flux[i], alpha=0.2)

    ax = axes[1]
    ax.plot(snia_flux[i], alpha=0.2)
    
    ax = axes[2]
    ax.plot(snib_flux[i], alpha=0.2)
    
    ax = axes[3]
    ax.plot(snibc_flux[i], alpha=0.2)
    
    ax = axes[4]
    ax.plot(snic_flux[i], alpha=0.2)
    
    ax = axes[5]
    ax.plot(sniin_flux[i], alpha=0.2)

    ax = axes[6]
    ax.plot(sniilp_flux[i], alpha=0.2)
    
    ax = axes[7]
    ax.plot(sniip_flux[i], alpha=0.2)
    
    ax = axes[8]
    ax.plot(kn_flux[i], alpha=0.2)
    
axes[0].set_title('galaxy spectra')
axes[1].set_title('galaxy + SN Ia spectra')
axes[2].set_title('galaxy + SN Ib spectra')
axes[3].set_title('galaxy + SN Ib/c spectra')
axes[4].set_title('galaxy + SN Ic spectra')
axes[5].set_title('galaxy + SN IIn spectra')
axes[6].set_title('galaxy + SN IIL/P spectra')
axes[7].set_title('galaxy + SN IIP spectra')
axes[8].set_title('galaxy + KN spectra')

fig.tight_layout()

# %% [markdown]
# ### Set up Training Sets and Labels
#
# 0. "host" spectra based only on BGS templates
# 0. "snia" spectra based on BGS + SN Ia templates
# 0. "snib" spectra based on BGS + SN Ib templates
# 0. "snibc" spectra based on BGS + SN Ib/c templates
# 0. "snic" spectra based on BGS + SN Ic templates
# 0. "sniin" spectra based on BGS + SN IIn templates
# 0. "sniip" spectra based on BGS + SN IIL/P templates
# 0. "sniip" spectra based on BGS + SN IIP templates
# 0. "kn" spectra based on BGS + KN templates

# %%
x = np.concatenate([galaxy_flux, 
                    snia_flux,
                    snib_flux,
                    snibc_flux,
                    snic_flux,
                    sniin_flux,
                    sniilp_flux,
                    sniip_flux,
                    kn_flux
                   ]).reshape(-1, nbins, 1)

labels = ['Galaxy',
          'SN Ia',
          'SN Ib',
          'SN Ib/c',
          'SN Ic',
          'SN IIn',
          'SN IIL/P',
          'SN IIP',
          'KN']
ntypes = len(labels)

# Convert y-label array to appropriate categorical array
from tensorflow.keras.utils import to_categorical

y = to_categorical(
        np.concatenate([np.full(ngalaxy, 0), 
                        np.full(nsnia, 1),
                        np.full(nsnib, 2),
                        np.full(nsnibc, 3),
                        np.full(nsnic, 4),
                        np.full(nsniin, 5),
                        np.full(nsniilp, 6),
                        np.full(nsniip, 7),
                        np.full(nkn, 8)
                       ]))

# %%
x.shape, y.shape
# Out:
# ((86937, 150, 1), (86937, 9))

# %% [markdown]
# ## CNN Network Setup
#
# Train network with TensorFlow+Keras.

# %%
import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model

# %%
def network(input_shape, ncat, learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1):
    """Define the CNN structure.
    
    Parameters
    ----------
    input_shape : int
        Shape of the input spectra.
    ncat : int
        Number of categories.
    learning_rate : float
        Learning rate.
    reg : float
        Regularization factor.
    dropout : float
        Dropout rate.
    seed : int
        Seed of initializer.
    
    Returns
    -------
    model : tensorflow.keras.Model
        A model instance of the network.
    """
    X_input = Input(input_shape, name='Input_Spec')

    # First convolutional layer.
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Second convolutional layer.
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Third convolutional layer.
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Fourth convolutional layer.
    with backend.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Flatten to fully connected dense layer.
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    # Output layer with sigmoid activation.
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l2(reg),
              activation='softmax',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    
    # Set up optimizer, loss function, and optimization metrics.
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = network((nbins, 1), ncat=y.shape[1])

# %%
model.summary()
# Out:
# Model: "SNnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Spec (InputLayer)      [(None, 150, 1)]          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 150, 8)            48
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 150, 8)            32
# _________________________________________________________________
# activation_8 (Activation)    (None, 150, 8)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 75, 8)             0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 75, 16)            656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 75, 16)            64
# _________________________________________________________________
# activation_9 (Activation)    (None, 75, 16)            0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 37, 16)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 37, 32)            2592
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 37, 32)            128
# _________________________________________________________________
# activation_10 (Activation)   (None, 37, 32)            0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 18, 32)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 18, 64)            10304
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 18, 64)            256
# _________________________________________________________________
# activation_11 (Activation)   (None, 18, 64)            0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 9, 64)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               147712
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Output_Classes (Dense)       (None, 9)                 2313
# =================================================================
# Total params: 164,105
# Trainable params: 163,865
# Non-trainable params: 240
# _________________________________________________________________

# %%
'''tf.keras.utils.plot_model(model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
    )'''
# Out:
# 'tf.keras.utils.plot_model(model,\n    to_file="model.png",\n    show_shapes=True,\n    show_layer_names=True,\n    rankdir="TB",\n    expand_nested=True,\n    dpi=96,\n    )'

# %% [markdown]
# ## Train and Test
#
# Split the data into training and testing (validation) samples and fit the network weights.

# %%
batch = 65
epoch = 200

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=40)
mc = ModelCheckpoint('b{}_e{}_best_model.h5'.format(batch, epoch), monitor='val_loss', mode='min', verbose=1, save_best_only=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
hist = model.fit(x_train, y_train, batch_size=batch, epochs=epoch, validation_data=(x_test, y_test), shuffle=True, verbose=True, callbacks=[es, mc])
# Out:
# Epoch 1/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 4.3173 - accuracy: 0.4184
# Epoch 00001: val_loss improved from inf to 3.21870, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 26s 26ms/step - loss: 4.3173 - accuracy: 0.4184 - val_loss: 3.2187 - val_accuracy: 0.5430
# Epoch 2/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 2.6919 - accuracy: 0.5746
# Epoch 00002: val_loss improved from 3.21870 to 2.34932, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 25s 25ms/step - loss: 2.6908 - accuracy: 0.5748 - val_loss: 2.3493 - val_accuracy: 0.5854
# Epoch 3/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 2.0748 - accuracy: 0.6124
# Epoch 00003: val_loss improved from 2.34932 to 1.89830, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 24s 24ms/step - loss: 2.0748 - accuracy: 0.6124 - val_loss: 1.8983 - val_accuracy: 0.6207
# Epoch 4/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.7677 - accuracy: 0.6327
# Epoch 00004: val_loss improved from 1.89830 to 1.68240, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.7677 - accuracy: 0.6327 - val_loss: 1.6824 - val_accuracy: 0.6374
# Epoch 5/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.5917 - accuracy: 0.6474
# Epoch 00005: val_loss improved from 1.68240 to 1.54567, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.5917 - accuracy: 0.6474 - val_loss: 1.5457 - val_accuracy: 0.6442
# Epoch 6/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.4830 - accuracy: 0.6549
# Epoch 00006: val_loss improved from 1.54567 to 1.47294, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.4830 - accuracy: 0.6549 - val_loss: 1.4729 - val_accuracy: 0.6489
# Epoch 7/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.4082 - accuracy: 0.6628
# Epoch 00007: val_loss improved from 1.47294 to 1.43858, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.4082 - accuracy: 0.6628 - val_loss: 1.4386 - val_accuracy: 0.6484
# Epoch 8/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.3560 - accuracy: 0.6697
# Epoch 00008: val_loss improved from 1.43858 to 1.36964, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.3566 - accuracy: 0.6695 - val_loss: 1.3696 - val_accuracy: 0.6631
# Epoch 9/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.3166 - accuracy: 0.6753
# Epoch 00009: val_loss improved from 1.36964 to 1.35100, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 20s 20ms/step - loss: 1.3166 - accuracy: 0.6753 - val_loss: 1.3510 - val_accuracy: 0.6560
# Epoch 10/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.2869 - accuracy: 0.6785
# Epoch 00010: val_loss improved from 1.35100 to 1.29213, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.2868 - accuracy: 0.6785 - val_loss: 1.2921 - val_accuracy: 0.6756
# Epoch 11/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.2661 - accuracy: 0.6819
# Epoch 00011: val_loss improved from 1.29213 to 1.28657, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.2661 - accuracy: 0.6819 - val_loss: 1.2866 - val_accuracy: 0.6740
# Epoch 12/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.2459 - accuracy: 0.6840
# Epoch 00012: val_loss did not improve from 1.28657
# 1004/1004 [==============================] - 25s 24ms/step - loss: 1.2459 - accuracy: 0.6840 - val_loss: 1.3035 - val_accuracy: 0.6594
# Epoch 13/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.2299 - accuracy: 0.6860
# Epoch 00013: val_loss improved from 1.28657 to 1.28054, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.2298 - accuracy: 0.6861 - val_loss: 1.2805 - val_accuracy: 0.6660
# Epoch 14/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.2173 - accuracy: 0.6881
# Epoch 00014: val_loss improved from 1.28054 to 1.24170, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.2173 - accuracy: 0.6881 - val_loss: 1.2417 - val_accuracy: 0.6826
# Epoch 15/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.2042 - accuracy: 0.6913
# Epoch 00015: val_loss did not improve from 1.24170
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.2043 - accuracy: 0.6913 - val_loss: 1.2469 - val_accuracy: 0.6770
# Epoch 16/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1940 - accuracy: 0.6928
# Epoch 00016: val_loss did not improve from 1.24170
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.1940 - accuracy: 0.6928 - val_loss: 1.2444 - val_accuracy: 0.6738
# Epoch 17/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1868 - accuracy: 0.6937
# Epoch 00017: val_loss improved from 1.24170 to 1.20766, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.1868 - accuracy: 0.6936 - val_loss: 1.2077 - val_accuracy: 0.6873
# Epoch 18/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.1775 - accuracy: 0.6962
# Epoch 00018: val_loss did not improve from 1.20766
# 1004/1004 [==============================] - 25s 24ms/step - loss: 1.1778 - accuracy: 0.6961 - val_loss: 1.2639 - val_accuracy: 0.6585
# Epoch 19/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1729 - accuracy: 0.6953
# Epoch 00019: val_loss did not improve from 1.20766
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.1729 - accuracy: 0.6953 - val_loss: 1.2380 - val_accuracy: 0.6750
# Epoch 20/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.1639 - accuracy: 0.6974
# Epoch 00020: val_loss did not improve from 1.20766
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.1640 - accuracy: 0.6973 - val_loss: 1.2437 - val_accuracy: 0.6701
# Epoch 21/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.1573 - accuracy: 0.6986
# Epoch 00021: val_loss improved from 1.20766 to 1.19184, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 24s 24ms/step - loss: 1.1572 - accuracy: 0.6987 - val_loss: 1.1918 - val_accuracy: 0.6882
# Epoch 22/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1523 - accuracy: 0.7000
# Epoch 00022: val_loss did not improve from 1.19184
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1523 - accuracy: 0.7000 - val_loss: 1.2547 - val_accuracy: 0.6613
# Epoch 23/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.1468 - accuracy: 0.7005
# Epoch 00023: val_loss did not improve from 1.19184
# 1004/1004 [==============================] - 24s 24ms/step - loss: 1.1469 - accuracy: 0.7005 - val_loss: 1.2862 - val_accuracy: 0.6461
# Epoch 24/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1402 - accuracy: 0.7012
# Epoch 00024: val_loss did not improve from 1.19184
# 1004/1004 [==============================] - 27s 27ms/step - loss: 1.1402 - accuracy: 0.7012 - val_loss: 1.2785 - val_accuracy: 0.6538
# Epoch 25/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.1377 - accuracy: 0.7020
# Epoch 00025: val_loss did not improve from 1.19184
# 1004/1004 [==============================] - 27s 27ms/step - loss: 1.1378 - accuracy: 0.7019 - val_loss: 1.2392 - val_accuracy: 0.6663
# Epoch 26/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.1357 - accuracy: 0.7030
# Epoch 00026: val_loss improved from 1.19184 to 1.18050, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 28s 28ms/step - loss: 1.1357 - accuracy: 0.7030 - val_loss: 1.1805 - val_accuracy: 0.6856
# Epoch 27/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.1283 - accuracy: 0.7050
# Epoch 00027: val_loss improved from 1.18050 to 1.18007, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 28s 28ms/step - loss: 1.1281 - accuracy: 0.7051 - val_loss: 1.1801 - val_accuracy: 0.6849
# Epoch 28/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.1257 - accuracy: 0.7041
# Epoch 00028: val_loss improved from 1.18007 to 1.15222, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 29s 29ms/step - loss: 1.1257 - accuracy: 0.7041 - val_loss: 1.1522 - val_accuracy: 0.6971
# Epoch 29/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1232 - accuracy: 0.7046
# Epoch 00029: val_loss did not improve from 1.15222
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1231 - accuracy: 0.7047 - val_loss: 1.1718 - val_accuracy: 0.6893
# Epoch 30/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.1184 - accuracy: 0.7055
# Epoch 00030: val_loss did not improve from 1.15222
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1182 - accuracy: 0.7056 - val_loss: 1.2194 - val_accuracy: 0.6763
# Epoch 31/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1148 - accuracy: 0.7064
# Epoch 00031: val_loss did not improve from 1.15222
# 1004/1004 [==============================] - 25s 24ms/step - loss: 1.1148 - accuracy: 0.7064 - val_loss: 1.1961 - val_accuracy: 0.6760
# Epoch 32/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.1115 - accuracy: 0.7057
# Epoch 00032: val_loss improved from 1.15222 to 1.14778, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.1115 - accuracy: 0.7058 - val_loss: 1.1478 - val_accuracy: 0.6960
# Epoch 33/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.1094 - accuracy: 0.7065
# Epoch 00033: val_loss did not improve from 1.14778
# 1004/1004 [==============================] - 26s 25ms/step - loss: 1.1093 - accuracy: 0.7065 - val_loss: 1.1602 - val_accuracy: 0.6922
# Epoch 34/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.1066 - accuracy: 0.7086
# Epoch 00034: val_loss improved from 1.14778 to 1.14004, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1068 - accuracy: 0.7086 - val_loss: 1.1400 - val_accuracy: 0.7027
# Epoch 35/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1027 - accuracy: 0.7102
# Epoch 00035: val_loss did not improve from 1.14004
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1028 - accuracy: 0.7102 - val_loss: 1.1660 - val_accuracy: 0.6858
# Epoch 36/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.1004 - accuracy: 0.7107
# Epoch 00036: val_loss did not improve from 1.14004
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.1004 - accuracy: 0.7107 - val_loss: 1.1516 - val_accuracy: 0.6962
# Epoch 37/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0979 - accuracy: 0.7109
# Epoch 00037: val_loss did not improve from 1.14004
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.0979 - accuracy: 0.7109 - val_loss: 1.1597 - val_accuracy: 0.6882
# Epoch 38/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0957 - accuracy: 0.7128
# Epoch 00038: val_loss did not improve from 1.14004
# 1004/1004 [==============================] - 25s 25ms/step - loss: 1.0957 - accuracy: 0.7128 - val_loss: 1.1514 - val_accuracy: 0.6866
# Epoch 39/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0929 - accuracy: 0.7110
# Epoch 00039: val_loss did not improve from 1.14004
# 1004/1004 [==============================] - 24s 24ms/step - loss: 1.0932 - accuracy: 0.7108 - val_loss: 1.1835 - val_accuracy: 0.6771
# Epoch 40/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0908 - accuracy: 0.7117
# Epoch 00040: val_loss improved from 1.14004 to 1.13973, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.0909 - accuracy: 0.7116 - val_loss: 1.1397 - val_accuracy: 0.6911
# Epoch 41/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0882 - accuracy: 0.7118
# Epoch 00041: val_loss did not improve from 1.13973
# 1004/1004 [==============================] - 26s 25ms/step - loss: 1.0881 - accuracy: 0.7118 - val_loss: 1.1887 - val_accuracy: 0.6752
# Epoch 42/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0823 - accuracy: 0.7130
# Epoch 00042: val_loss did not improve from 1.13973
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0821 - accuracy: 0.7131 - val_loss: 1.1586 - val_accuracy: 0.6883
# Epoch 43/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0814 - accuracy: 0.7121
# Epoch 00043: val_loss improved from 1.13973 to 1.10988, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 23s 22ms/step - loss: 1.0816 - accuracy: 0.7121 - val_loss: 1.1099 - val_accuracy: 0.7032
# Epoch 44/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0792 - accuracy: 0.7142
# Epoch 00044: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0791 - accuracy: 0.7143 - val_loss: 1.1484 - val_accuracy: 0.6886
# Epoch 45/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0757 - accuracy: 0.7149
# Epoch 00045: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0756 - accuracy: 0.7149 - val_loss: 1.1921 - val_accuracy: 0.6729
# Epoch 46/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0741 - accuracy: 0.7168
# Epoch 00046: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0739 - accuracy: 0.7169 - val_loss: 1.1361 - val_accuracy: 0.6959
# Epoch 47/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0711 - accuracy: 0.7150
# Epoch 00047: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0711 - accuracy: 0.7150 - val_loss: 1.1474 - val_accuracy: 0.6919
# Epoch 48/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0684 - accuracy: 0.7171
# Epoch 00048: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0684 - accuracy: 0.7171 - val_loss: 1.1523 - val_accuracy: 0.6847
# Epoch 49/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0651 - accuracy: 0.7178
# Epoch 00049: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0651 - accuracy: 0.7178 - val_loss: 1.1265 - val_accuracy: 0.6976
# Epoch 50/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0640 - accuracy: 0.7177
# Epoch 00050: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 21ms/step - loss: 1.0639 - accuracy: 0.7177 - val_loss: 1.1546 - val_accuracy: 0.6828
# Epoch 51/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0609 - accuracy: 0.7185
# Epoch 00051: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0610 - accuracy: 0.7185 - val_loss: 1.1515 - val_accuracy: 0.6839
# Epoch 52/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0618 - accuracy: 0.7173
# Epoch 00052: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 22ms/step - loss: 1.0618 - accuracy: 0.7173 - val_loss: 1.1421 - val_accuracy: 0.6928
# Epoch 53/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0600 - accuracy: 0.7192
# Epoch 00053: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0600 - accuracy: 0.7192 - val_loss: 1.1303 - val_accuracy: 0.6947
# Epoch 54/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0546 - accuracy: 0.7207
# Epoch 00054: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0546 - accuracy: 0.7207 - val_loss: 1.1319 - val_accuracy: 0.6887
# Epoch 55/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0533 - accuracy: 0.7202
# Epoch 00055: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0531 - accuracy: 0.7203 - val_loss: 1.1555 - val_accuracy: 0.6866
# Epoch 56/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0538 - accuracy: 0.7209
# Epoch 00056: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0538 - accuracy: 0.7209 - val_loss: 1.1503 - val_accuracy: 0.6835
# Epoch 57/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0517 - accuracy: 0.7207
# Epoch 00057: val_loss did not improve from 1.10988
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0517 - accuracy: 0.7207 - val_loss: 1.1334 - val_accuracy: 0.6904
# Epoch 58/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0495 - accuracy: 0.7221
# Epoch 00058: val_loss improved from 1.10988 to 1.10473, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0495 - accuracy: 0.7220 - val_loss: 1.1047 - val_accuracy: 0.7044
# Epoch 59/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0473 - accuracy: 0.7225
# Epoch 00059: val_loss did not improve from 1.10473
# 1004/1004 [==============================] - 24s 23ms/step - loss: 1.0472 - accuracy: 0.7225 - val_loss: 1.1253 - val_accuracy: 0.6923
# Epoch 60/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0463 - accuracy: 0.7213
# Epoch 00060: val_loss did not improve from 1.10473
# 1004/1004 [==============================] - 24s 24ms/step - loss: 1.0462 - accuracy: 0.7213 - val_loss: 1.1275 - val_accuracy: 0.6942
# Epoch 61/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0444 - accuracy: 0.7219
# Epoch 00061: val_loss did not improve from 1.10473
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0446 - accuracy: 0.7218 - val_loss: 1.1069 - val_accuracy: 0.7037
# Epoch 62/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0435 - accuracy: 0.7234
# Epoch 00062: val_loss did not improve from 1.10473
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0435 - accuracy: 0.7234 - val_loss: 1.1901 - val_accuracy: 0.6617
# Epoch 63/200
#  460/1004 [============>.................] - ETA: 11s - loss: 1.0267 - accuracy: 0.7285
# Epoch 00065: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0377 - accuracy: 0.7257 - val_loss: 1.1317 - val_accuracy: 0.6914
# Epoch 66/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0352 - accuracy: 0.7247
# Epoch 00066: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 21ms/step - loss: 1.0351 - accuracy: 0.7247 - val_loss: 1.0921 - val_accuracy: 0.7058
# Epoch 67/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0335 - accuracy: 0.7266
# Epoch 00067: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0334 - accuracy: 0.7266 - val_loss: 1.1190 - val_accuracy: 0.6987
# Epoch 68/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0311 - accuracy: 0.7272
# Epoch 00068: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0310 - accuracy: 0.7272 - val_loss: 1.1189 - val_accuracy: 0.6964
# Epoch 69/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0336 - accuracy: 0.7260
# Epoch 00069: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0336 - accuracy: 0.7260 - val_loss: 1.1095 - val_accuracy: 0.7023
# Epoch 70/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0288 - accuracy: 0.7271
# Epoch 00070: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0288 - accuracy: 0.7271 - val_loss: 1.1341 - val_accuracy: 0.6928
# Epoch 71/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0285 - accuracy: 0.7270
# Epoch 00071: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0285 - accuracy: 0.7270 - val_loss: 1.1226 - val_accuracy: 0.6926
# Epoch 72/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 1.0274 - accuracy: 0.7274
# Epoch 00072: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0274 - accuracy: 0.7274 - val_loss: 1.1121 - val_accuracy: 0.7009
# Epoch 73/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0292 - accuracy: 0.7266
# Epoch 00073: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0291 - accuracy: 0.7267 - val_loss: 1.1480 - val_accuracy: 0.6829
# Epoch 74/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0243 - accuracy: 0.7282
# Epoch 00074: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0241 - accuracy: 0.7283 - val_loss: 1.1269 - val_accuracy: 0.6926
# Epoch 75/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0227 - accuracy: 0.7280
# Epoch 00075: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 26s 26ms/step - loss: 1.0226 - accuracy: 0.7281 - val_loss: 1.1424 - val_accuracy: 0.6899
# Epoch 76/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0254 - accuracy: 0.7278
# Epoch 00076: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 29s 29ms/step - loss: 1.0254 - accuracy: 0.7278 - val_loss: 1.1055 - val_accuracy: 0.7064
# Epoch 77/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0214 - accuracy: 0.7285
# Epoch 00077: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0214 - accuracy: 0.7285 - val_loss: 1.1722 - val_accuracy: 0.6783
# Epoch 78/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0186 - accuracy: 0.7306
# Epoch 00078: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0185 - accuracy: 0.7306 - val_loss: 1.1046 - val_accuracy: 0.7013
# Epoch 79/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0187 - accuracy: 0.7294
# Epoch 00079: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0186 - accuracy: 0.7294 - val_loss: 1.1424 - val_accuracy: 0.6888
# Epoch 80/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0180 - accuracy: 0.7300
# Epoch 00080: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 24s 24ms/step - loss: 1.0180 - accuracy: 0.7300 - val_loss: 1.1300 - val_accuracy: 0.6924
# Epoch 81/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0177 - accuracy: 0.7306
# Epoch 00081: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0177 - accuracy: 0.7306 - val_loss: 1.1106 - val_accuracy: 0.7019
# Epoch 82/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0177 - accuracy: 0.7305
# Epoch 00082: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 22ms/step - loss: 1.0178 - accuracy: 0.7304 - val_loss: 1.1245 - val_accuracy: 0.6976
# Epoch 83/200
# 1004/1004 [==============================] - ETA: 0s - loss: 1.0182 - accuracy: 0.7291
# Epoch 00083: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 23ms/step - loss: 1.0182 - accuracy: 0.7291 - val_loss: 1.1039 - val_accuracy: 0.7034
# Epoch 84/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0152 - accuracy: 0.7318
# Epoch 00084: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0151 - accuracy: 0.7319 - val_loss: 1.1320 - val_accuracy: 0.6930
# Epoch 85/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0109 - accuracy: 0.7324
# Epoch 00085: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 20s 20ms/step - loss: 1.0110 - accuracy: 0.7324 - val_loss: 1.1168 - val_accuracy: 0.6996
# Epoch 86/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0117 - accuracy: 0.7314
# Epoch 00086: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0118 - accuracy: 0.7314 - val_loss: 1.1030 - val_accuracy: 0.7018
# Epoch 87/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 1.0127 - accuracy: 0.7295
# Epoch 00087: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0124 - accuracy: 0.7297 - val_loss: 1.1094 - val_accuracy: 0.7022
# Epoch 88/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0081 - accuracy: 0.7323
# Epoch 00088: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 23s 22ms/step - loss: 1.0080 - accuracy: 0.7323 - val_loss: 1.1463 - val_accuracy: 0.6824
# Epoch 89/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0108 - accuracy: 0.7325
# Epoch 00089: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0107 - accuracy: 0.7325 - val_loss: 1.1132 - val_accuracy: 0.6974
# Epoch 90/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0062 - accuracy: 0.7347
# Epoch 00090: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 20ms/step - loss: 1.0065 - accuracy: 0.7346 - val_loss: 1.1841 - val_accuracy: 0.6732
# Epoch 91/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 1.0073 - accuracy: 0.7328
# Epoch 00091: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0078 - accuracy: 0.7326 - val_loss: 1.1059 - val_accuracy: 0.7026
# Epoch 92/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0070 - accuracy: 0.7330
# Epoch 00092: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 21ms/step - loss: 1.0071 - accuracy: 0.7329 - val_loss: 1.0884 - val_accuracy: 0.7084
# Epoch 93/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0079 - accuracy: 0.7341
# Epoch 00093: val_loss did not improve from 1.08658
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0080 - accuracy: 0.7341 - val_loss: 1.1589 - val_accuracy: 0.6850
# Epoch 94/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0054 - accuracy: 0.7332
# Epoch 00094: val_loss improved from 1.08658 to 1.08007, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0055 - accuracy: 0.7332 - val_loss: 1.0801 - val_accuracy: 0.7132
# Epoch 95/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0025 - accuracy: 0.7339
# Epoch 00095: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0025 - accuracy: 0.7339 - val_loss: 1.0979 - val_accuracy: 0.7042
# Epoch 96/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 1.0028 - accuracy: 0.7349
# Epoch 00096: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0029 - accuracy: 0.7349 - val_loss: 1.0999 - val_accuracy: 0.7051
# Epoch 97/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0021 - accuracy: 0.7352
# Epoch 00097: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 1.0021 - accuracy: 0.7352 - val_loss: 1.1045 - val_accuracy: 0.7030
# Epoch 98/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 1.0016 - accuracy: 0.7344
# Epoch 00098: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 21s 21ms/step - loss: 1.0016 - accuracy: 0.7344 - val_loss: 1.1193 - val_accuracy: 0.6947
# Epoch 99/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9989 - accuracy: 0.7360
# Epoch 00099: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9991 - accuracy: 0.7360 - val_loss: 1.1260 - val_accuracy: 0.6920
# Epoch 100/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9996 - accuracy: 0.7350
# Epoch 00100: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9997 - accuracy: 0.7349 - val_loss: 1.1425 - val_accuracy: 0.6849
# Epoch 101/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9998 - accuracy: 0.7354
# Epoch 00101: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9994 - accuracy: 0.7355 - val_loss: 1.1685 - val_accuracy: 0.6790
# Epoch 102/200
# 1004/1004 [==============================] - ETA: 0s - loss: 0.9983 - accuracy: 0.7356
# Epoch 00102: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 21ms/step - loss: 0.9983 - accuracy: 0.7356 - val_loss: 1.1006 - val_accuracy: 0.7032
# Epoch 103/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9996 - accuracy: 0.7358 ETA
# Epoch 00103: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 23s 23ms/step - loss: 0.9997 - accuracy: 0.7358 - val_loss: 1.0951 - val_accuracy: 0.7045
# Epoch 104/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9929 - accuracy: 0.7373
# Epoch 00104: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9931 - accuracy: 0.7372 - val_loss: 1.0919 - val_accuracy: 0.7097
# Epoch 105/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9933 - accuracy: 0.7376
# Epoch 00105: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 20s 20ms/step - loss: 0.9933 - accuracy: 0.7377 - val_loss: 1.1345 - val_accuracy: 0.6874
# Epoch 106/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9930 - accuracy: 0.7381
# Epoch 00106: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9929 - accuracy: 0.7381 - val_loss: 1.1059 - val_accuracy: 0.6993
# Epoch 107/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9939 - accuracy: 0.7393
# Epoch 00107: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9939 - accuracy: 0.7393 - val_loss: 1.0935 - val_accuracy: 0.7056
# Epoch 108/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9928 - accuracy: 0.7363
# Epoch 00108: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9928 - accuracy: 0.7363 - val_loss: 1.1990 - val_accuracy: 0.6593
# Epoch 109/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9931 - accuracy: 0.7374
# Epoch 00109: val_loss did not improve from 1.08007
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9929 - accuracy: 0.7374 - val_loss: 1.1496 - val_accuracy: 0.6843
# Epoch 110/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9910 - accuracy: 0.7397
# Epoch 00110: val_loss improved from 1.08007 to 1.06991, saving model to b65_e200_best_model.h5
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9910 - accuracy: 0.7397 - val_loss: 1.0699 - val_accuracy: 0.7167
# Epoch 111/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9924 - accuracy: 0.7391
# Epoch 00111: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 23s 23ms/step - loss: 0.9925 - accuracy: 0.7391 - val_loss: 1.1011 - val_accuracy: 0.7011
# Epoch 112/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9923 - accuracy: 0.7381
# Epoch 00112: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9921 - accuracy: 0.7382 - val_loss: 1.0881 - val_accuracy: 0.7092
# Epoch 113/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9883 - accuracy: 0.7406
# Epoch 00113: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9883 - accuracy: 0.7406 - val_loss: 1.0965 - val_accuracy: 0.7022
# Epoch 114/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9910 - accuracy: 0.7396
# Epoch 00114: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 21ms/step - loss: 0.9910 - accuracy: 0.7396 - val_loss: 1.1222 - val_accuracy: 0.6993
# Epoch 115/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9903 - accuracy: 0.7391
# Epoch 00115: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9903 - accuracy: 0.7391 - val_loss: 1.1019 - val_accuracy: 0.7051
# Epoch 116/200
# 1004/1004 [==============================] - ETA: 0s - loss: 0.9893 - accuracy: 0.7400
# Epoch 00116: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9893 - accuracy: 0.7400 - val_loss: 1.1125 - val_accuracy: 0.6987
# Epoch 117/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9862 - accuracy: 0.7404
# Epoch 00117: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9862 - accuracy: 0.7404 - val_loss: 1.1603 - val_accuracy: 0.6796
# Epoch 118/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9876 - accuracy: 0.7414
# Epoch 00118: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9875 - accuracy: 0.7414 - val_loss: 1.1194 - val_accuracy: 0.6964
# Epoch 119/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9852 - accuracy: 0.7418 ETA: 0s - loss: 0
# Epoch 00119: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 23s 23ms/step - loss: 0.9854 - accuracy: 0.7416 - val_loss: 1.1103 - val_accuracy: 0.6988
# Epoch 120/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9862 - accuracy: 0.7420
# Epoch 00120: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9863 - accuracy: 0.7419 - val_loss: 1.1307 - val_accuracy: 0.6945
# Epoch 121/200
# 1004/1004 [==============================] - ETA: 0s - loss: 0.9857 - accuracy: 0.7404
# Epoch 00121: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9857 - accuracy: 0.7404 - val_loss: 1.1039 - val_accuracy: 0.6996
# Epoch 122/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9847 - accuracy: 0.7409
# Epoch 00122: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 21ms/step - loss: 0.9847 - accuracy: 0.7409 - val_loss: 1.0920 - val_accuracy: 0.7049
# Epoch 123/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9817 - accuracy: 0.7416
# Epoch 00123: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9817 - accuracy: 0.7416 - val_loss: 1.1002 - val_accuracy: 0.7008
# Epoch 124/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9795 - accuracy: 0.7450
# Epoch 00124: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9794 - accuracy: 0.7449 - val_loss: 1.1036 - val_accuracy: 0.6996
# Epoch 125/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9825 - accuracy: 0.7420
# Epoch 00125: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9824 - accuracy: 0.7420 - val_loss: 1.1120 - val_accuracy: 0.7000
# Epoch 126/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9811 - accuracy: 0.7423
# Epoch 00126: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9812 - accuracy: 0.7423 - val_loss: 1.1197 - val_accuracy: 0.6924
# Epoch 127/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9794 - accuracy: 0.7430
# Epoch 00127: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9794 - accuracy: 0.7429 - val_loss: 1.1390 - val_accuracy: 0.6926
# Epoch 128/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9796 - accuracy: 0.7424
# Epoch 00128: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9797 - accuracy: 0.7424 - val_loss: 1.0887 - val_accuracy: 0.7048
# Epoch 129/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9783 - accuracy: 0.7448
# Epoch 00129: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9784 - accuracy: 0.7448 - val_loss: 1.1065 - val_accuracy: 0.7002
# Epoch 130/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9774 - accuracy: 0.7446
# Epoch 00130: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9774 - accuracy: 0.7445 - val_loss: 1.1380 - val_accuracy: 0.6882
# Epoch 131/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9771 - accuracy: 0.7451
# Epoch 00131: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9768 - accuracy: 0.7451 - val_loss: 1.1047 - val_accuracy: 0.7032
# Epoch 132/200
# 1004/1004 [==============================] - ETA: 0s - loss: 0.9761 - accuracy: 0.7443
# Epoch 00132: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9761 - accuracy: 0.7443 - val_loss: 1.1196 - val_accuracy: 0.6981
# Epoch 133/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9804 - accuracy: 0.7429
# Epoch 00133: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 20ms/step - loss: 0.9803 - accuracy: 0.7429 - val_loss: 1.1167 - val_accuracy: 0.7019
# Epoch 134/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9771 - accuracy: 0.7452
# Epoch 00134: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9770 - accuracy: 0.7452 - val_loss: 1.2755 - val_accuracy: 0.6444
# Epoch 135/200
# 1000/1004 [============================>.] - ETA: 0s - loss: 0.9768 - accuracy: 0.7448
# Epoch 00135: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9774 - accuracy: 0.7446 - val_loss: 1.0843 - val_accuracy: 0.7112
# Epoch 136/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9759 - accuracy: 0.7452
# Epoch 00136: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9758 - accuracy: 0.7453 - val_loss: 1.0848 - val_accuracy: 0.7091
# Epoch 137/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9742 - accuracy: 0.7461
# Epoch 00137: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 20ms/step - loss: 0.9742 - accuracy: 0.7460 - val_loss: 1.1757 - val_accuracy: 0.6838
# Epoch 138/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9758 - accuracy: 0.7443
# Epoch 00138: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 20s 20ms/step - loss: 0.9758 - accuracy: 0.7443 - val_loss: 1.0945 - val_accuracy: 0.7053
# Epoch 139/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9723 - accuracy: 0.7469
# Epoch 00139: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9722 - accuracy: 0.7469 - val_loss: 1.1039 - val_accuracy: 0.7027
# Epoch 140/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9747 - accuracy: 0.7452
# Epoch 00140: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9749 - accuracy: 0.7451 - val_loss: 1.0895 - val_accuracy: 0.7080
# Epoch 141/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9713 - accuracy: 0.7467
# Epoch 00141: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9714 - accuracy: 0.7466 - val_loss: 1.2007 - val_accuracy: 0.6649
# Epoch 142/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9721 - accuracy: 0.7475
# Epoch 00142: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9722 - accuracy: 0.7474 - val_loss: 1.1073 - val_accuracy: 0.7009
# Epoch 143/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9718 - accuracy: 0.7463
# Epoch 00143: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9718 - accuracy: 0.7464 - val_loss: 1.1247 - val_accuracy: 0.6974
# Epoch 144/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9699 - accuracy: 0.7488
# Epoch 00144: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 21ms/step - loss: 0.9698 - accuracy: 0.7488 - val_loss: 1.1209 - val_accuracy: 0.6944
# Epoch 145/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9708 - accuracy: 0.7478
# Epoch 00145: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9709 - accuracy: 0.7478 - val_loss: 1.1194 - val_accuracy: 0.6953
# Epoch 146/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9701 - accuracy: 0.7458
# Epoch 00146: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 23s 23ms/step - loss: 0.9702 - accuracy: 0.7457 - val_loss: 1.1278 - val_accuracy: 0.6966
# Epoch 147/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9706 - accuracy: 0.7485
# Epoch 00147: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 22s 22ms/step - loss: 0.9707 - accuracy: 0.7485 - val_loss: 1.1430 - val_accuracy: 0.6917
# Epoch 148/200
# 1003/1004 [============================>.] - ETA: 0s - loss: 0.9673 - accuracy: 0.7488
# Epoch 00148: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 21s 21ms/step - loss: 0.9674 - accuracy: 0.7487 - val_loss: 1.1165 - val_accuracy: 0.6989
# Epoch 149/200
# 1001/1004 [============================>.] - ETA: 0s - loss: 0.9693 - accuracy: 0.7463
# Epoch 00149: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 23s 23ms/step - loss: 0.9696 - accuracy: 0.7462 - val_loss: 1.1093 - val_accuracy: 0.7026
# Epoch 150/200
# 1002/1004 [============================>.] - ETA: 0s - loss: 0.9660 - accuracy: 0.7504
# Epoch 00150: val_loss did not improve from 1.06991
# 1004/1004 [==============================] - 26s 25ms/step - loss: 0.9660 - accuracy: 0.7504 - val_loss: 1.1172 - val_accuracy: 0.6985
# Epoch 00150: early stopping

# %% [markdown]
# ## Performance
#
# ### Loss and Accuracy
#
# Plot loss and accuracy as a function of epoch.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5), sharex=True)

nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, hist.history['accuracy'], label='acc')
ax.plot(epochs, hist.history['val_accuracy'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.,1.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
#        ylim=(0.,2.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

fig.tight_layout()
plt.savefig('b{}_e{}_accuracy.png'.format(batch, epoch))

# %% [markdown]
# ### ROC Curve and Precision-Recall
#
# Plot both the ROC curves per class and the class-averaged ROC curve.

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[4.1229278e-02, 3.1469946e-03, 1.5176237e-02, ..., 4.9282587e-03,
#         2.6981202e-03, 6.6685730e-01],
#        [4.4262551e-06, 1.4254665e-06, 6.3722720e-05, ..., 1.5885737e-06,
#         7.2151724e-06, 9.7927928e-01],
#        [3.8845342e-02, 1.5092633e-02, 1.8832974e-01, ..., 1.1379867e-02,
#         1.0463540e-02, 1.2896904e-01],
#        ...,
#        [5.5469410e-03, 4.2809565e-02, 2.8933841e-01, ..., 5.0234806e-04,
#         8.9697344e-03, 9.0168715e-03],
#        [4.5026240e-01, 3.2452390e-02, 7.9546399e-02, ..., 7.9183757e-02,
#         1.9464416e-02, 3.7090912e-02],
#        [7.2736883e-01, 2.4856364e-02, 1.1583895e-01, ..., 3.8962774e-03,
#         8.2689291e-03, 1.0284293e-04]], dtype=float32)

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])
    
    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')
    
    pre[i], rec[i], _ = precision_recall_curve(y_test[:,i], y_pred[:,i])
    
    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])
        
ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_test.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_test, y_pred)),
       aspect='equal')

fig.tight_layout()
plt.savefig('b{}_e{}_metrics.png'.format(batch, epoch))

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')

plt.tight_layout()
plt.savefig('b{}_e{}_matrix.png'.format(batch, epoch))

# %%
model.save('b{}_e{}_9label_model'.format(batch, epoch))
# Out:
# INFO:tensorflow:Assets written to: b65_e200_9label_model/assets

# %%
model.save('b{}_e{}_9label.h5'.format(batch, epoch))

# %%
nb_path = '/global/u1/l/lehsani/timedomain/desitrip/docs/nb'

if not '1_b{}_e{}_9label'.format(batch, epoch) in os.listdir(nb_path):
    os.mkdir('1_b{}_e{}_9label'.format(batch, epoch))
    num = 1
else:
    folders = []
    for file in os.listdir(nb_path):
        if file.endswith('b{}_e{}_9label'.format(batch, epoch)):
            folders.append(file)
        else:
            continue
    folders = sorted(folders)
    num = folders[-1].split('_')[0]
    num = int(num) + 1
    os.mkdir('{}_b{}_e{}_9label'.format(num, batch, epoch))

for file in os.listdir(nb_path):
    if file == 'b{}_e{}_9label'.format(batch, epoch):
        continue
    if file.startswith('b{}_e{}'.format(batch, epoch)):
        shutil.move('{}/{}'.format(nb_path, file), '{}/{}_b{}_e{}_9label/{}'.format(nb_path, num, batch, epoch, file))
