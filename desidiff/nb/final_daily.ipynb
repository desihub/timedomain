# %%
import os
import sys
from glob import glob

module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import desispec
from desispec.io import read_spectra, write_spectra
from desispec.spectra import Spectra

from desiutil.log import get_logger, DEBUG

from desidiff.src.group_tiles import *
from desidiff.src.dates_to_process import *
from desidiff.src.coadd import *
from desidiff.src.scores import *
from desidiff.src.ContinuumFitFilter_desidiff import *

from timedomain.sp_utils import SkyPortal as sp
import requests
import datetime
import heapq
import time
import copy
import numpy
from astropy.time import Time
from astropy.table import Table, vstack, unique, SortedArray
import h5py

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from IPython import display

# %%
#SkyPortal token:
secret_file = "/global/cfs/cdirs/desi/science/td/secrets/desidiff_sp.txt"
with open(secret_file, 'r') as file:
    token = file.read().replace('\n', '')
headers = {'Authorization': f'token {token}'}

filter_name = 'DESIDIFF'

all_plots_pdf = PdfPages("All_plots.pdf")

# %%
# read in and store in one place all the fibermap information in the spectra files

night = 20210608 
for current_filename in glob(f"/global/project/projectdirs/desi/spectro/redux/daily/tiles/cumulative/*/{night}/spectra-*.fits"):
    tile = current_filename.split('/')[-3]
    petal = current_filename.split('-')[1]
    ### daily_spectra, the precursor to current spectra, before coadding, to select night, unique target ids, and individual target ids
    ### spectra.select functionality will not work once coadded with coaddition.coadd_cameras
    daily_spectra = ((read_spectra(current_filename)).select(nights = night))

    table = Table.read(current_filename, format='fits',hdu=1, memmap=True) 
    ##### DAVE'S ADDITION ##############
    targetcols = [i for i in table.colnames if i[-7:] =='_TARGET']
    nonzerocheck = [True in k for k in [[j != 0 for j in table[targetcols][i]] for i in range(len(table))]]
    #a really ugly line, basically generates a list of bools, 
    #True if there is at least one nonzero element in all columns ending in _TARGET
    table.remove_rows([i for i, val in enumerate(nonzerocheck) if not val])
    #This gets the index of all False values from the previous list and removes those rows
    table = table['TARGETID','TARGET_RA','TARGET_DEC','TILEID','OBJTYPE','PETAL_LOC','FIBERSTATUS','NIGHT']
    ######## END DAVE'S ADDITION ############
    table = table[numpy.logical_and(table['OBJTYPE']=='TGT', table['FIBERSTATUS']==0)]


    for ref_filename in glob(f"/global/cfs/cdirs/desi/spectro/redux/*/tiles/cumulative/{tile}/*/coadd-{petal}-{tile}*.fits"):
        print(ref_filename)
        try:
            if ref_filename.split('/')[-6] == 'fuji' or ref_filename.split('/')[-6] == 'guadalupe':
                prev_spectra = read_spectra(ref_filename)

                gen = (t for t in daily_spectra.target_ids()[numpy.where(daily_spectra.fibermap['OBJTYPE']=='TGT')] if t in prev_spectra.target_ids()[numpy.where(prev_spectra.fibermap['OBJTYPE']=='TGT')])
                for t in gen:
                    ### grab ra and dec values for use in SkyPortal functionality later
                    ra_dec = (table[table['TARGETID']==t]['TARGET_RA'][0], table[table['TARGETID']==t]['TARGET_DEC'][0])
                    ### match target ids
                    current_spectra = desispec.coaddition.coadd_cameras(daily_spectra.select(targets = t))
                    ref_spectra = desispec.coaddition.coadd_cameras(prev_spectra.select(targets = t))

                    norm = normalization(current_spectra.flux, current_spectra.mask, ref_spectra.flux, ref_spectra.mask)

                    # need to instantiate a Spectra object for the difference. 
                    ### Using 'dif_spectra = Spectra()' is bugging on dif_spectra.mask type=NoneType, can't assign.
                    #### dif_spectra = current_spectra
                    ### copy.deepcopy() is deprecated as memory expensive
                    dif_spectra = copy.deepcopy(current_spectra)
                    #### any problem with hardcoding in 'brz' for key in the following:
                    for key in (current_spectra.flux).keys():
                        current_spectra.flux[key] = current_spectra.flux[key]/norm
                        current_spectra.ivar[key] = current_spectra.ivar[key]*norm**2  
                        # subtraction of current and reference fluxes
                        dif_spectra.flux[key] = current_spectra.flux[key] - ref_spectra.flux[key]
                        ### couldn't dif_spectra.mask[key] == 2 by summing current.mask and reference.mask
                        # summation of current and reference masks
                        dif_spectra.mask[key] = current_spectra.mask[key] + ref_spectra.mask[key]
                        # inverted summation of current and spectra inverse variance
                        ### still returning RuntimeWarning: divide by zero encountered in true_divide but not in infinite loop for the moment
                        dif_spectra.ivar[key] = 1./(1./current_spectra.ivar[key] + 1./ref_spectra.ivar[key])

                    # mean-subtracted difference
                    dif_flux_clipped = clipmean(dif_spectra.flux, dif_spectra.ivar, dif_spectra.mask)

                    # filters 
                    # Difference spectrum may have broadband signal
                    perband_filter = perband_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask)

                    # fractional increase
                    perband_inc = perband_increase(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ref_spectra.flux, ref_spectra.ivar, ref_spectra.mask)

                    # Difference spectrum may have high-frequency signal
                    perres_filter_broad = perconv_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ncon = 100, nsig = 17)

                    perres_filter_narrow = perconv_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ncon = 5, nsig = 10)

                    ### grab redrock data required for filters using redshift (zinfo)
                    current_filename = (current_filename.replace('spectra','redrock')).replace('fits', 'h5')

                    with h5py.File(current_filename, "r") as f:
                        zinfo = f['zfit']['t']['zfit'][0]['z']

                    # Search for signature lines of TDEs, only interested in Galaxies
                    linetable = line_finder(dif_spectra.wave, dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, zinfo)
                    # print(night, linetable)
                    Hline_score = Hline_filter(linetable)
                    # deriv_score = deriv_filter(dif_flux_clipped, dif_spectra.ivar,dif_spectra.mask)

                    #broadband
                    bblogic = any(numpy.logical_and(numpy.array(list(perband_filter.values()))>10, numpy.array(list(perband_inc.values()))>0.25))
                    narrowlinelogic = perres_filter_narrow >=2
                    broadlinelogic = perres_filter_broad >=3
                    # TDElogic = any([TDE_score == 2, TDE_score == 3, TDE_score == 4, TDE_score == 5])
                    Hlinelogic = any([Hline_score >= 1])
                    # derivlogic = any([deriv_score >= 3])

                    logic = [bblogic, narrowlinelogic,  broadlinelogic, Hlinelogic]
                    logic_name = ['Broadband', 'narrow line', 'broad line','Hline'] #must be in same order as logic!, use as mask
                    logic_name = numpy.ma.masked_array(logic_name, mask = [not i for i in logic])

                    plt.clf()
                    pdf_per_tile = PdfPages(str(tile)+".pdf")

                    plt.rcParams["figure.figsize"] = (20,6)
                    ####if any(logic):
                        #Uncomment next line if you want to print only those TargetIds that get plotted
                    #processed(t, tile, night)
                    fig = plt.figure()
                    #for b in dif_spectra.wave.keys():
                    ### have hardcoded 'brz' in place of for b in keys()...
                    for key in (current_spectra.flux).keys():
                        w=numpy.where(dif_spectra.mask[key][0] == 0)

                        plt.plot(dif_spectra.wave[key][w], dif_spectra.flux[key][0][w], color='red', label = 'Difference')
                        plt.plot(current_spectra.wave[key][w], current_spectra.flux[key][0][w], color='blue', alpha=0.5, label = 'New Spectrum')
                        plt.plot(ref_spectra.wave[key][w],ref_spectra.flux[key][0][w],color='green',alpha=0.5, label = 'Reference Spectrum')

                        plt.legend()
                        plt.xlabel('Wavelength (Å)')
                        plt.ylabel('Flux') 
                        plt.title(str(t) + "  " + str(night) + "  " + str(tile)  + "  " + str(logic_name))

                        plt.savefig(pdf_per_tile, format = 'pdf')
                        plt.savefig(all_plots_pdf, format = 'pdf')
                        plt.close()
                    """
                    #SkyPortal functionality begins:
                    #SkyPortal's Id for the object
                    objID = 'DESI{}'.format(str(t))

                    #Code to check if this object already exists in SkyPortal. If not, create it

                    response = requests.get("https://desi-skyportal.lbl.gov/api/candidates/{}".format(objID), headers={"Authorization": f"token {token}"})
                    if response.status_code == 400:
                        obj_data = {
                                "ra": ra_dec[0], #RA is required when creating a new object.
                                "dec": ra_dec[1], #Same for DEC
                                "id": objID,
                                "redshift": zinfo,
                                "filter_ids": [sp.filter_id(filter_name)],
                                "passed_at": str(datetime.datetime.utcnow()) #UTC time when the object passed the filter
                                }

                        response = requests.post(
                                "https://desi-skyportal.lbl.gov/api/candidates",
                                json = obj_data,
                                headers = {"Authorization": f"token {token}"})

                    #Now, we send the differenced spectrum to SkyPortal
                    #First, check if the same spectrum already exists under the object
                    response = requests.get("https://desi-skyportal.lbl.gov/api/sources/{}/spectra".format(objID),headers={"Authorization": f"token {token}"})
                    post = True
                    # for i in range (len(response.json()['data']['spectra'])):
                    #     if (wavelengths == response.json()['data']['spectra'][i]['wavelengths'] and flux == response.json()['data']['spectra'][i]['fluxes']):
                    #         post = False
                    #Only if the exact same spectrum doesn't already exist, upload it.
                    if post:
                        #Send difference spectrum to SP:
                        dif_spectrum_data = {
                                "obj_id": objID,
                                "wavelengths": dif_spectra.wave['brz'][w].tolist(),
                                "fluxes": dif_spectra.flux['brz'][0][w].tolist(),
                                "observed_at": str(night)[:4]+'-'+str(night)[4:6]+'-'+str(night)[6:]+' '+'00:00:00.000000', # Date converted into UTC time format
                                "origin": "DESIDIFF_dif_spectrum", #Only the difference spectrum gets this tag in order to distinguish it on SkyPortal
                                "group_ids": [sp.group_id("DESI")],
                                "instrument_id": sp.instrument_id()
                                }
                        response = requests.post(
                                    '{}/api/spectrum'.format(sp.url),
                                    json= dif_spectrum_data,
                                    headers={"Authorization": f"token {token}"}) 

                        #Send new spectra to SP:
                        current_spectra_data = {
                            "obj_id": objID,
                            "wavelengths":current_spectra.wave['brz'][w].tolist(),
                            "fluxes": current_spectra.flux['brz'][0][w].tolist(),
                            "observed_at": str(night)[:4]+'-'+str(night)[4:6]+'-'+str(night)[6:]+' '+'00:00:00.000000', # Date converted into UTC time format
                            "origin": "DESIDIFF",
                            "group_ids": [sp.group_id("DESI")],
                            "instrument_id": sp.instrument_id()
                            }
                        response = requests.post(
                                '{}/api/spectrum'.format(sp.url),
                                json= current_spectra_data,
                                headers={"Authorization": f"token {token}"}) 

                        #Code to find the ref_night that is closest to current_night to be used as 'observed_at' for SP
                        if ref_filename.split('/')[-6] == 'fuji':
                            ref_night = 20201214
                        elif ref_filename.split('/')[-6] == 'guadalupe':
                            ref_night = 20210514
                        current_night = datetime.datetime(int(str(night)[:4]), int(str(night)[4:6]), int(str(night)[6:]))
                        closest_night = datetime.datetime(int(str(ref_night)[:4]), int(str(ref_night)[4:6]), int(str(ref_night)[6:]))



                        ref_spectra_data = {
                            "obj_id": objID,
                            "wavelengths": ref_spectra.wave['brz'][w].tolist(),
                            "fluxes": ref_spectra.flux['brz'][0][w].tolist(),
                            "observed_at": str(closest_night),
                            "origin": "DESIDIFF",
                            "group_ids": [sp.group_id("DESI")],
                            "instrument_id": sp.instrument_id()
                            }
                        response = requests.post(
                                '{}/api/spectrum'.format(sp.url),
                                json= ref_spectra_data,
                                headers={"Authorization": f"token {token}"})    
                        """
                    all_plots_pdf.close()
                    pdf_per_tile.close()
        except:
            pass
# Out:
# INFO:spectra.py:291:read_spectra: iotime 0.571 sec to read spectra-6-1097-thru20210608.fits at 2022-07-06T19:01:01.153731
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.444 sec to read coadd-6-1097-thru20210608.fits at 2022-07-06T19:01:03.449608
# /tmp/ipykernel_22677/1769395560.py:56: RuntimeWarning: divide by zero encountered in true_divide
#   dif_spectra.ivar[key] = 1./(1./current_spectra.ivar[key] + 1./ref_spectra.ivar[key])
# INFO:spectra.py:291:read_spectra: iotime 0.511 sec to read spectra-4-1097-thru20210608.fits at 2022-07-06T19:01:04.769524
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.451 sec to read coadd-4-1097-thru20210608.fits at 2022-07-06T19:01:06.990467
# INFO:spectra.py:291:read_spectra: iotime 0.511 sec to read spectra-8-1097-thru20210608.fits at 2022-07-06T19:01:13.952347
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.514 sec to read coadd-8-1097-thru20210608.fits at 2022-07-06T19:01:16.191701
# /global/cscratch1/sd/clepart/timedomain/desidiff/src/scores.py:76: RuntimeWarning: divide by zero encountered in true_divide
#   newston[b]=numpy.array(numpy.convolve(newy[b][0], conk, mode='valid') / numpy.sqrt(numpy.convolve(1/ivar[b][0], conk, mode='valid')))
# INFO:spectra.py:291:read_spectra: iotime 0.518 sec to read spectra-1-1097-thru20210608.fits at 2022-07-06T19:01:23.264997
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.445 sec to read coadd-1-1097-thru20210608.fits at 2022-07-06T19:01:25.392126
# INFO:spectra.py:291:read_spectra: iotime 0.416 sec to read spectra-9-1097-thru20210608.fits at 2022-07-06T19:01:32.446629
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.393 sec to read coadd-9-1097-thru20210608.fits at 2022-07-06T19:01:34.680152
# INFO:spectra.py:291:read_spectra: iotime 0.462 sec to read spectra-7-1097-thru20210608.fits at 2022-07-06T19:01:36.683008
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.491 sec to read coadd-7-1097-thru20210608.fits at 2022-07-06T19:01:38.824354
# INFO:spectra.py:291:read_spectra: iotime 0.402 sec to read spectra-3-1097-thru20210608.fits at 2022-07-06T19:01:40.908927
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22677/1769395560.py in <module>
#       7     ### daily_spectra, the precursor to current spectra, before coadding, to select night, unique target ids, and individual target ids
#       8     ### spectra.select functionality will not work once coadded with coaddition.coadd_cameras
# ----> 9     daily_spectra = ((read_spectra(current_filename)).select(nights = night))
#      10
#      11     table = Table.read(current_filename, format='fits',hdu=1, memmap=True)
#
# /global/common/software/desi/cori/desiconda/20211217-2.0.0/code/desispec/master/py/desispec/spectra.py in select(self, nights, exposures, bands, targets, fibers, invert, return_index)
#     373             raise RuntimeError("selection has no spectra")
#     374
# --> 375         sp = self._get_slice(keep_rows, bands=keep_bands)
#     376
#     377         if return_index:
#
# /global/common/software/desi/cori/desiconda/20211217-2.0.0/code/desispec/master/py/desispec/spectra.py in _get_slice(self, index, bands)
#     292                 mask[band] = self.mask[band][index].copy()
#     293             if self.resolution_data is not None:
# --> 294                 rdat[band] = self.resolution_data[band][index].copy()
#     295             if self.extra is not None:
#     296                 extra[band] = dict()
#
# KeyboardInterrupt:

# %%
night_arr = getUnprocessedDates()

# %%
# read in and store in one place all the fibermap information in the spectra files
#night_arr = getUnprocessedDates()

for night in night_arr:   
    for current_filename in glob(f"/global/project/projectdirs/desi/spectro/redux/daily/tiles/cumulative/*/{night}/spectra-*.fits"):
        tile = current_filename.split('/')[-3]
        petal = current_filename.split('-')[1]
        ### daily_spectra, the precursor to current spectra, before coadding, to select night, unique target ids, and individual target ids
        ### spectra.select functionality will not work once coadded with coaddition.coadd_cameras
        try:
            daily_spectra = ((read_spectra(current_filename)).select(nights = night))
        except:
            daily_spectra = ((read_spectra(current_filename)).select(nights = (night-1)))

        table = Table.read(current_filename, format='fits',hdu=1, memmap=True) 
        ##### DAVE'S ADDITION ##############
        targetcols = [i for i in table.colnames if i[-7:] =='_TARGET']
        nonzerocheck = [True in k for k in [[j != 0 for j in table[targetcols][i]] for i in range(len(table))]]
        #a really ugly line, basically generates a list of bools, 
        #True if there is at least one nonzero element in all columns ending in _TARGET
        table.remove_rows([i for i, val in enumerate(nonzerocheck) if not val])
        #This gets the index of all False values from the previous list and removes those rows
        table = table['TARGETID','TARGET_RA','TARGET_DEC','TILEID','OBJTYPE','PETAL_LOC','FIBERSTATUS','NIGHT']
        ######## END DAVE'S ADDITION ############
        table = table[numpy.logical_and(table['OBJTYPE']=='TGT', table['FIBERSTATUS']==0)]


        for ref_filename in glob(f"/global/cfs/cdirs/desi/spectro/redux/*/tiles/cumulative/{tile}/*/coadd-{petal}-{tile}*.fits"):
            print(ref_filename)
            try:
                if ref_filename.split('/')[-6] == 'fuji' or ref_filename.split('/')[-6] == 'guadalupe':
                    prev_spectra = read_spectra(ref_filename)

                    gen = (t for t in daily_spectra.target_ids()[numpy.where(daily_spectra.fibermap['OBJTYPE']=='TGT')] if t in prev_spectra.target_ids()[numpy.where(prev_spectra.fibermap['OBJTYPE']=='TGT')])
                    for t in gen:
                        print(t)
                        ### grab ra and dec values for use in SkyPortal functionality later
                        #ra_dec = (table[table['TARGETID']==t]['TARGET_RA'][0], table[table['TARGETID']==t]['TARGET_DEC'][0])
                        ra, dec = table['TARGETID' == t]['TARGET_RA'], table['TARGETID' == t]['TARGET_DEC']
                        ### match target ids
                        current_spectra = desispec.coaddition.coadd_cameras(daily_spectra.select(targets = t))
                        ref_spectra = desispec.coaddition.coadd_cameras(prev_spectra.select(targets = t))
                           
                        print('coaddition.coadd_cameras completed')
                        norm = normalization(current_spectra.flux, current_spectra.mask, ref_spectra.flux, ref_spectra.mask)

                        # need to instantiate a Spectra object for the difference. 
                        ### Using 'dif_spectra = Spectra()' is bugging on dif_spectra.mask type=NoneType, can't assign.
                        #### dif_spectra = current_spectra
                        ### copy.deepcopy() is deprecated as memory expensive
                        dif_spectra = copy.deepcopy(current_spectra)
                        #### any problem with hardcoding in 'brz' for key in the following:
                        for key in (current_spectra.flux).keys():
                            current_spectra.flux[key] = current_spectra.flux[key]/norm
                            current_spectra.ivar[key] = current_spectra.ivar[key]*norm**2 
                            print('normalization completed')
                            # subtraction of current and reference fluxes
                            dif_spectra.flux[key] = current_spectra.flux[key] - ref_spectra.flux[key]
                            print('flux subtraction completed')
                            ### couldn't dif_spectra.mask[key] == 2 by summing current.mask and reference.mask
                            # summation of current and reference masks
                            dif_spectra.mask[key] = current_spectra.mask[key] + ref_spectra.mask[key]
                            print('mask summation completed')
                            # inverted summation of current and spectra inverse variance
                            ### still returning RuntimeWarning: divide by zero encountered in true_divide but not in infinite loop for the moment
                            dif_spectra.ivar[key] = 1./(1./current_spectra.ivar[key] + 1./ref_spectra.ivar[key])
                            print('ivar inverse summation completed')

                        # mean-subtracted difference
                        dif_flux_clipped = clipmean(dif_spectra.flux, dif_spectra.ivar, dif_spectra.mask)
                        print('clipmean completed')

                        # filters 
                        # Difference spectrum may have broadband signal
                        perband_filter = perband_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask)

                        # fractional increase
                        perband_inc = perband_increase(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ref_spectra.flux, ref_spectra.ivar, ref_spectra.mask)

                        # Difference spectrum may have high-frequency signal
                        perres_filter_broad = perconv_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ncon = 100, nsig = 17)

                        perres_filter_narrow = perconv_SN(dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, ncon = 5, nsig = 10)
                        print('SN filters completed')
                        ### grab redrock data required for filters using redshift (zinfo)
                        current_filename = (current_filename.replace('spectra','redrock')).replace('fits', 'h5')

                        with h5py.File(current_filename, "r") as f:
                            zinfo = f['zfit'][str(t)]['zfit'][0]['z']

                        # Search for signature lines of TDEs, only interested in Galaxies
                        linetable = line_finder(dif_spectra.wave, dif_flux_clipped, dif_spectra.ivar, dif_spectra.mask, zinfo)
                        # print(night, linetable)
                        Hline_score = Hline_filter(linetable)
                        # deriv_score = deriv_filter(dif_flux_clipped, dif_spectra.ivar,dif_spectra.mask)
                        print('sig. line filters completed')
                        #broadband
                        bblogic = any(numpy.logical_and(numpy.array(list(perband_filter.values()))>10, numpy.array(list(perband_inc.values()))>0.25))
                        narrowlinelogic = perres_filter_narrow >=2
                        broadlinelogic = perres_filter_broad >=3
                        # TDElogic = any([TDE_score == 2, TDE_score == 3, TDE_score == 4, TDE_score == 5])
                        Hlinelogic = any([Hline_score >= 1])
                        # derivlogic = any([deriv_score >= 3])
                        print('broadband logic completed')
                        logic = [bblogic, narrowlinelogic,  broadlinelogic, Hlinelogic]
                        logic_name = ['Broadband', 'narrow line', 'broad line','Hline'] #must be in same order as logic!, use as mask
                        logic_name = numpy.ma.masked_array(logic_name, mask = [not i for i in logic])

                        plt.clf()
                        pdf_per_tile = PdfPages(str(tile)+".pdf")

                        plt.rcParams["figure.figsize"] = (20,6)
                        ####if any(logic):
                            #Uncomment next line if you want to print only those TargetIds that get plotted
                        #processed(t, tile, night)
                        fig = plt.figure()
                        for key in (current_spectra.flux).keys():
                            w=numpy.where(dif_spectra.mask[key][0] == 0)

                            plt.plot(dif_spectra.wave[key][w], dif_spectra.flux[key][0][w], color='red', label = 'Difference')
                            plt.plot(current_spectra.wave[key][w], current_spectra.flux[key][0][w], color='blue', alpha=0.5, label = 'New Spectrum')
                            plt.plot(ref_spectra.wave[key][w],ref_spectra.flux[key][0][w],color='green',alpha=0.5, label = 'Reference Spectrum')

                            plt.legend()
                            plt.xlabel('Wavelength (Å)')
                            plt.ylabel('Flux') 
                            plt.title(str(t) + "  " + str(night) + "  " + str(tile)  + "  " + str(logic_name))

                            plt.savefig(pdf_per_tile, format = 'pdf')
                            plt.savefig(all_plots_pdf, format = 'pdf')
                            plt.close()
                        """
                        #SkyPortal functionality begins:
                        #SkyPortal's Id for the object
                        objID = 'DESI{}'.format(str(t))

                        #Code to check if this object already exists in SkyPortal. If not, create it

                        response = requests.get("https://desi-skyportal.lbl.gov/api/candidates/{}".format(objID), headers={"Authorization": f"token {token}"})
                        if response.status_code == 400:
                            obj_data = {
                                    "ra": ra, #RA is required when creating a new object.
                                    "dec": dec, #Same for DEC
                                    "id": objID,
                                    "redshift": zinfo,
                                    "filter_ids": [sp.filter_id(filter_name)],
                                    "passed_at": str(datetime.datetime.utcnow()) #UTC time when the object passed the filter
                                    }

                            response = requests.post(
                                    "https://desi-skyportal.lbl.gov/api/candidates",
                                    json = obj_data,
                                    headers = {"Authorization": f"token {token}"})

                        #Now, we send the differenced spectrum to SkyPortal
                        #First, check if the same spectrum already exists under the object
                        response = requests.get("https://desi-skyportal.lbl.gov/api/sources/{}/spectra".format(objID),headers={"Authorization": f"token {token}"})
                        post = True
                        # for i in range (len(response.json()['data']['spectra'])):
                        #     if (wavelengths == response.json()['data']['spectra'][i]['wavelengths'] and flux == response.json()['data']['spectra'][i]['fluxes']):
                        #         post = False
                        #Only if the exact same spectrum doesn't already exist, upload it.
                        if post:
                            #Send difference spectrum to SP:
                            dif_spectrum_data = {
                                    "obj_id": objID,
                                    "wavelengths": dif_spectra.wave['brz'][w].tolist(),
                                    "fluxes": dif_spectra.flux['brz'][0][w].tolist(),
                                    "observed_at": str(night)[:4]+'-'+str(night)[4:6]+'-'+str(night)[6:]+' '+'00:00:00.000000', # Date converted into UTC time format
                                    "origin": "DESIDIFF_dif_spectrum", #Only the difference spectrum gets this tag in order to distinguish it on SkyPortal
                                    "group_ids": [sp.group_id("DESI")],
                                    "instrument_id": sp.instrument_id()
                                    }
                            response = requests.post(
                                        '{}/api/spectrum'.format(sp.url),
                                        json= dif_spectrum_data,
                                        headers={"Authorization": f"token {token}"}) 

                            #Send new spectra to SP:
                            current_spectra_data = {
                                "obj_id": objID,
                                "wavelengths":current_spectra.wave['brz'][w].tolist(),
                                "fluxes": current_spectra.flux['brz'][0][w].tolist(),
                                "observed_at": str(night)[:4]+'-'+str(night)[4:6]+'-'+str(night)[6:]+' '+'00:00:00.000000', # Date converted into UTC time format
                                "origin": "DESIDIFF",
                                "group_ids": [sp.group_id("DESI")],
                                "instrument_id": sp.instrument_id()
                                }
                            response = requests.post(
                                    '{}/api/spectrum'.format(sp.url),
                                    json= current_spectra_data,
                                    headers={"Authorization": f"token {token}"}) 

                            #Code to find the ref_night that is closest to current_night to be used as 'observed_at' for SP
                            if ref_filename.split('/')[-6] == 'fuji':
                                ref_night = 20201214
                            elif ref_filename.split('/')[-6] == 'guadalupe':
                                ref_night = 20210514
                            current_night = datetime.datetime(int(str(night)[:4]), int(str(night)[4:6]), int(str(night)[6:]))
                            closest_night = datetime.datetime(int(str(ref_night)[:4]), int(str(ref_night)[4:6]), int(str(ref_night)[6:]))



                            ref_spectra_data = {
                                "obj_id": objID,
                                "wavelengths": ref_spectra.wave['brz'][w].tolist(),
                                "fluxes": ref_spectra.flux['brz'][0][w].tolist(),
                                "observed_at": str(closest_night),
                                "origin": "DESIDIFF",
                                "group_ids": [sp.group_id("DESI")],
                                "instrument_id": sp.instrument_id()
                                }
                            response = requests.post(
                                    '{}/api/spectrum'.format(sp.url),
                                    json= ref_spectra_data,
                                    headers={"Authorization": f"token {token}"})    
                        """
                        all_plots_pdf.close()
                        pdf_per_tile.close()
            except:
                pass
# Out:
# len(night_arr): 240
# --- get unprocessed dates took:  161.48444390296936 seconds ---
# INFO:spectra.py:291:read_spectra: iotime 0.524 sec to read spectra-5-21163-thru20210607.fits at 2022-07-06T19:04:52.702019
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-5-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-5-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-5-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.463 sec to read coadd-5-21163-thru20210607.fits at 2022-07-06T19:04:55.028337
# /tmp/ipykernel_22677/3915911600.py:57: RuntimeWarning: divide by zero encountered in true_divide
#   dif_spectra.ivar[key] = 1./(1./current_spectra.ivar[key] + 1./ref_spectra.ivar[key])
# INFO:spectra.py:291:read_spectra: iotime 0.525 sec to read spectra-4-21163-thru20210607.fits at 2022-07-06T19:05:02.440668
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-4-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-4-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-4-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.528 sec to read coadd-4-21163-thru20210607.fits at 2022-07-06T19:05:04.908580
# INFO:spectra.py:291:read_spectra: iotime 0.524 sec to read spectra-3-21163-thru20210607.fits at 2022-07-06T19:05:12.026366
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-3-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-3-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-3-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.532 sec to read coadd-3-21163-thru20210607.fits at 2022-07-06T19:05:14.274793
# INFO:spectra.py:291:read_spectra: iotime 0.517 sec to read spectra-9-21163-thru20210607.fits at 2022-07-06T19:05:21.376620
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-9-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-9-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-9-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.502 sec to read coadd-9-21163-thru20210607.fits at 2022-07-06T19:05:23.578334
# INFO:spectra.py:291:read_spectra: iotime 0.515 sec to read spectra-2-21163-thru20210607.fits at 2022-07-06T19:05:30.474145
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-2-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-2-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-2-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.535 sec to read coadd-2-21163-thru20210607.fits at 2022-07-06T19:05:32.673016
# INFO:spectra.py:291:read_spectra: iotime 0.548 sec to read spectra-6-21163-thru20210607.fits at 2022-07-06T19:05:39.868038
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-6-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-6-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-6-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.399 sec to read coadd-6-21163-thru20210607.fits at 2022-07-06T19:05:42.057929
# INFO:spectra.py:291:read_spectra: iotime 0.498 sec to read spectra-1-21163-thru20210607.fits at 2022-07-06T19:05:49.051939
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-1-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-1-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-1-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.502 sec to read coadd-1-21163-thru20210607.fits at 2022-07-06T19:05:51.285777
# INFO:spectra.py:291:read_spectra: iotime 0.497 sec to read spectra-7-21163-thru20210607.fits at 2022-07-06T19:05:58.316225
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-7-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-7-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-7-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.404 sec to read coadd-7-21163-thru20210607.fits at 2022-07-06T19:06:00.375386
# INFO:spectra.py:291:read_spectra: iotime 0.544 sec to read spectra-0-21163-thru20210607.fits at 2022-07-06T19:06:07.516951
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-0-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-0-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-0-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.479 sec to read coadd-0-21163-thru20210607.fits at 2022-07-06T19:06:09.778691
# INFO:spectra.py:291:read_spectra: iotime 0.451 sec to read spectra-8-21163-thru20210607.fits at 2022-07-06T19:06:16.762646
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21163/20210607/coadd-8-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21163/20210607/coadd-8-21163-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21163/20210607/coadd-8-21163-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.384 sec to read coadd-8-21163-thru20210607.fits at 2022-07-06T19:06:18.970202
# INFO:spectra.py:291:read_spectra: iotime 0.509 sec to read spectra-7-20077-thru20210607.fits at 2022-07-06T19:06:26.022141
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-7-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-7-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-7-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.437 sec to read coadd-7-20077-thru20210607.fits at 2022-07-06T19:06:28.208889
# INFO:spectra.py:291:read_spectra: iotime 0.445 sec to read spectra-5-20077-thru20210607.fits at 2022-07-06T19:06:35.138506
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-5-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-5-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-5-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.437 sec to read coadd-5-20077-thru20210607.fits at 2022-07-06T19:06:37.273200
# INFO:spectra.py:291:read_spectra: iotime 0.523 sec to read spectra-8-20077-thru20210607.fits at 2022-07-06T19:06:44.250225
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-8-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-8-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-8-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.474 sec to read coadd-8-20077-thru20210607.fits at 2022-07-06T19:06:46.422465
# INFO:spectra.py:291:read_spectra: iotime 0.445 sec to read spectra-3-20077-thru20210607.fits at 2022-07-06T19:06:53.350916
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-3-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-3-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-3-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.407 sec to read coadd-3-20077-thru20210607.fits at 2022-07-06T19:06:55.395628
# INFO:spectra.py:291:read_spectra: iotime 0.495 sec to read spectra-0-20077-thru20210607.fits at 2022-07-06T19:07:02.321819
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-0-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-0-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-0-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.431 sec to read coadd-0-20077-thru20210607.fits at 2022-07-06T19:07:04.408854
# INFO:spectra.py:291:read_spectra: iotime 0.412 sec to read spectra-6-20077-thru20210607.fits at 2022-07-06T19:07:11.358062
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-6-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-6-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-6-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.404 sec to read coadd-6-20077-thru20210607.fits at 2022-07-06T19:07:13.400199
# INFO:spectra.py:291:read_spectra: iotime 0.674 sec to read spectra-2-20077-thru20210607.fits at 2022-07-06T19:07:20.632777
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-2-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-2-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-2-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.563 sec to read coadd-2-20077-thru20210607.fits at 2022-07-06T19:07:23.037957
# INFO:spectra.py:291:read_spectra: iotime 0.629 sec to read spectra-1-20077-thru20210607.fits at 2022-07-06T19:07:30.157272
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-1-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-1-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-1-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.471 sec to read coadd-1-20077-thru20210607.fits at 2022-07-06T19:07:32.309260
# INFO:spectra.py:291:read_spectra: iotime 0.705 sec to read spectra-4-20077-thru20210607.fits at 2022-07-06T19:07:39.638913
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-4-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-4-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-4-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.628 sec to read coadd-4-20077-thru20210607.fits at 2022-07-06T19:07:42.000371
# INFO:spectra.py:291:read_spectra: iotime 0.789 sec to read spectra-9-20077-thru20210607.fits at 2022-07-06T19:07:49.304544
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20077/20210607/coadd-9-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20077/20210607/coadd-9-20077-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20077/20210607/coadd-9-20077-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.540 sec to read coadd-9-20077-thru20210607.fits at 2022-07-06T19:07:51.435368
# INFO:spectra.py:291:read_spectra: iotime 0.631 sec to read spectra-9-1078-thru20210607.fits at 2022-07-06T19:07:59.196213
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-9-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-9-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-9-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-9-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.600 sec to read coadd-9-1078-thru20210619.fits at 2022-07-06T19:08:01.756951
# INFO:spectra.py:291:read_spectra: iotime 0.501 sec to read spectra-0-1078-thru20210607.fits at 2022-07-06T19:08:09.079121
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-0-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-0-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-0-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-0-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.672 sec to read coadd-0-1078-thru20210619.fits at 2022-07-06T19:08:11.469492
# INFO:spectra.py:291:read_spectra: iotime 0.709 sec to read spectra-7-1078-thru20210607.fits at 2022-07-06T19:08:18.772065
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-7-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-7-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-7-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-7-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.461 sec to read coadd-7-1078-thru20210619.fits at 2022-07-06T19:08:20.920285
# INFO:spectra.py:291:read_spectra: iotime 0.504 sec to read spectra-4-1078-thru20210607.fits at 2022-07-06T19:08:27.737751
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-4-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-4-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-4-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-4-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.416 sec to read coadd-4-1078-thru20210619.fits at 2022-07-06T19:08:29.780535
# INFO:spectra.py:291:read_spectra: iotime 0.435 sec to read spectra-3-1078-thru20210607.fits at 2022-07-06T19:08:36.590471
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-3-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-3-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-3-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-3-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.436 sec to read coadd-3-1078-thru20210619.fits at 2022-07-06T19:08:38.805207
# INFO:spectra.py:291:read_spectra: iotime 0.504 sec to read spectra-6-1078-thru20210607.fits at 2022-07-06T19:08:45.591583
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-6-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-6-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-6-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-6-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.389 sec to read coadd-6-1078-thru20210619.fits at 2022-07-06T19:08:47.570683
# INFO:spectra.py:291:read_spectra: iotime 0.432 sec to read spectra-5-1078-thru20210607.fits at 2022-07-06T19:08:54.494698
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-5-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-5-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-5-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-5-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.385 sec to read coadd-5-1078-thru20210619.fits at 2022-07-06T19:08:56.575521
# INFO:spectra.py:291:read_spectra: iotime 0.449 sec to read spectra-8-1078-thru20210607.fits at 2022-07-06T19:09:03.504990
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-8-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-8-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-8-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-8-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.406 sec to read coadd-8-1078-thru20210619.fits at 2022-07-06T19:09:05.609786
# INFO:spectra.py:291:read_spectra: iotime 0.478 sec to read spectra-2-1078-thru20210607.fits at 2022-07-06T19:09:12.510653
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-2-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-2-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-2-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-2-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.438 sec to read coadd-2-1078-thru20210619.fits at 2022-07-06T19:09:14.817540
# INFO:spectra.py:291:read_spectra: iotime 0.432 sec to read spectra-1-1078-thru20210607.fits at 2022-07-06T19:09:21.724736
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1078/20210619/coadd-1-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210619/coadd-1-1078-thru20210619.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1078/20210607/coadd-1-1078-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1078/20210619/coadd-1-1078-thru20210619.fits
# INFO:spectra.py:291:read_spectra: iotime 0.408 sec to read coadd-1-1078-thru20210619.fits at 2022-07-06T19:09:23.795234
# INFO:spectra.py:291:read_spectra: iotime 0.418 sec to read spectra-0-20076-thru20210607.fits at 2022-07-06T19:09:30.519981
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-0-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-0-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-0-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.470 sec to read coadd-0-20076-thru20210607.fits at 2022-07-06T19:09:32.707068
# INFO:spectra.py:291:read_spectra: iotime 0.455 sec to read spectra-5-20076-thru20210607.fits at 2022-07-06T19:09:39.380821
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-5-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-5-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-5-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.380 sec to read coadd-5-20076-thru20210607.fits at 2022-07-06T19:09:41.270269
# INFO:spectra.py:291:read_spectra: iotime 0.509 sec to read spectra-6-20076-thru20210607.fits at 2022-07-06T19:09:48.054354
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-6-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-6-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-6-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.430 sec to read coadd-6-20076-thru20210607.fits at 2022-07-06T19:09:50.077546
# INFO:spectra.py:291:read_spectra: iotime 0.489 sec to read spectra-1-20076-thru20210607.fits at 2022-07-06T19:09:56.895961
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-1-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-1-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-1-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.419 sec to read coadd-1-20076-thru20210607.fits at 2022-07-06T19:09:58.906160
# INFO:spectra.py:291:read_spectra: iotime 0.461 sec to read spectra-4-20076-thru20210607.fits at 2022-07-06T19:10:05.603746
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-4-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-4-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-4-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.440 sec to read coadd-4-20076-thru20210607.fits at 2022-07-06T19:10:07.639937
# INFO:spectra.py:291:read_spectra: iotime 0.423 sec to read spectra-9-20076-thru20210607.fits at 2022-07-06T19:10:14.324709
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-9-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-9-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-9-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.374 sec to read coadd-9-20076-thru20210607.fits at 2022-07-06T19:10:16.406489
# INFO:spectra.py:291:read_spectra: iotime 0.465 sec to read spectra-8-20076-thru20210607.fits at 2022-07-06T19:10:23.147934
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-8-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-8-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-8-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.503 sec to read coadd-8-20076-thru20210607.fits at 2022-07-06T19:10:25.249892
# INFO:spectra.py:291:read_spectra: iotime 0.490 sec to read spectra-7-20076-thru20210607.fits at 2022-07-06T19:10:31.996189
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-7-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-7-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-7-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.395 sec to read coadd-7-20076-thru20210607.fits at 2022-07-06T19:10:33.961014
# INFO:spectra.py:291:read_spectra: iotime 0.489 sec to read spectra-3-20076-thru20210607.fits at 2022-07-06T19:10:40.673391
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-3-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-3-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-3-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.439 sec to read coadd-3-20076-thru20210607.fits at 2022-07-06T19:10:42.690207
# INFO:spectra.py:291:read_spectra: iotime 0.452 sec to read spectra-2-20076-thru20210607.fits at 2022-07-06T19:10:49.201605
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20076/20210607/coadd-2-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20076/20210607/coadd-2-20076-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20076/20210607/coadd-2-20076-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.394 sec to read coadd-2-20076-thru20210607.fits at 2022-07-06T19:10:51.234652
# INFO:spectra.py:291:read_spectra: iotime 0.405 sec to read spectra-6-21197-thru20210607.fits at 2022-07-06T19:10:57.806967
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-6-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-6-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-6-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.473 sec to read coadd-6-21197-thru20210607.fits at 2022-07-06T19:11:00.033240
# INFO:spectra.py:291:read_spectra: iotime 0.460 sec to read spectra-2-21197-thru20210607.fits at 2022-07-06T19:11:06.775745
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-2-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-2-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-2-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.444 sec to read coadd-2-21197-thru20210607.fits at 2022-07-06T19:11:08.781766
# INFO:spectra.py:291:read_spectra: iotime 0.421 sec to read spectra-8-21197-thru20210607.fits at 2022-07-06T19:11:15.402252
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-8-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-8-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-8-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.399 sec to read coadd-8-21197-thru20210607.fits at 2022-07-06T19:11:17.426738
# INFO:spectra.py:291:read_spectra: iotime 0.461 sec to read spectra-5-21197-thru20210607.fits at 2022-07-06T19:11:24.158855
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-5-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-5-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-5-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.406 sec to read coadd-5-21197-thru20210607.fits at 2022-07-06T19:11:26.331043
# INFO:spectra.py:291:read_spectra: iotime 0.436 sec to read spectra-9-21197-thru20210607.fits at 2022-07-06T19:11:33.122991
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-9-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-9-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-9-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.402 sec to read coadd-9-21197-thru20210607.fits at 2022-07-06T19:11:35.108189
# INFO:spectra.py:291:read_spectra: iotime 0.485 sec to read spectra-7-21197-thru20210607.fits at 2022-07-06T19:11:41.988253
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-7-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-7-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-7-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.408 sec to read coadd-7-21197-thru20210607.fits at 2022-07-06T19:11:43.977964
# INFO:spectra.py:291:read_spectra: iotime 0.414 sec to read spectra-0-21197-thru20210607.fits at 2022-07-06T19:11:50.640912
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-0-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-0-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-0-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.379 sec to read coadd-0-21197-thru20210607.fits at 2022-07-06T19:11:52.609531
# INFO:spectra.py:291:read_spectra: iotime 0.407 sec to read spectra-4-21197-thru20210607.fits at 2022-07-06T19:11:59.401877
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-4-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-4-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-4-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.394 sec to read coadd-4-21197-thru20210607.fits at 2022-07-06T19:12:01.392787
# INFO:spectra.py:291:read_spectra: iotime 0.515 sec to read spectra-3-21197-thru20210607.fits at 2022-07-06T19:12:08.121414
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-3-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-3-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-3-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.404 sec to read coadd-3-21197-thru20210607.fits at 2022-07-06T19:12:10.202924
# INFO:spectra.py:291:read_spectra: iotime 0.473 sec to read spectra-1-21197-thru20210607.fits at 2022-07-06T19:12:17.156271
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/21197/20210607/coadd-1-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/21197/20210607/coadd-1-21197-thru20210607.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/21197/20210607/coadd-1-21197-thru20210607.fits
# INFO:spectra.py:291:read_spectra: iotime 0.395 sec to read coadd-1-21197-thru20210607.fits at 2022-07-06T19:12:19.144877
# INFO:spectra.py:291:read_spectra: iotime 0.393 sec to read spectra-6-1097-thru20210608.fits at 2022-07-06T19:12:25.966856
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-6-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.369 sec to read coadd-6-1097-thru20210608.fits at 2022-07-06T19:12:28.056495
# INFO:spectra.py:291:read_spectra: iotime 0.386 sec to read spectra-4-1097-thru20210608.fits at 2022-07-06T19:12:34.641293
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-4-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.367 sec to read coadd-4-1097-thru20210608.fits at 2022-07-06T19:12:36.583265
# INFO:spectra.py:291:read_spectra: iotime 0.471 sec to read spectra-8-1097-thru20210608.fits at 2022-07-06T19:12:43.269578
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-8-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.379 sec to read coadd-8-1097-thru20210608.fits at 2022-07-06T19:12:45.201478
# INFO:spectra.py:291:read_spectra: iotime 0.477 sec to read spectra-1-1097-thru20210608.fits at 2022-07-06T19:12:51.924608
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-1-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.337 sec to read coadd-1-1097-thru20210608.fits at 2022-07-06T19:12:53.824688
# INFO:spectra.py:291:read_spectra: iotime 0.701 sec to read spectra-9-1097-thru20210608.fits at 2022-07-06T19:13:01.198124
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-9-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.477 sec to read coadd-9-1097-thru20210608.fits at 2022-07-06T19:13:03.428467
# INFO:spectra.py:291:read_spectra: iotime 0.710 sec to read spectra-7-1097-thru20210608.fits at 2022-07-06T19:13:10.583628
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-7-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.487 sec to read coadd-7-1097-thru20210608.fits at 2022-07-06T19:13:12.665236
# INFO:spectra.py:291:read_spectra: iotime 0.393 sec to read spectra-3-1097-thru20210608.fits at 2022-07-06T19:13:19.568288
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1097/20210608/coadd-3-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1097/20210608/coadd-3-1097-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1097/20210608/coadd-3-1097-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.701 sec to read coadd-3-1097-thru20210608.fits at 2022-07-06T19:13:21.833524
# INFO:spectra.py:291:read_spectra: iotime 0.484 sec to read spectra-5-20085-thru20210608.fits at 2022-07-06T19:15:13.337930
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20085/20210608/coadd-5-20085-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20085/20210608/coadd-5-20085-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20085/20210608/coadd-5-20085-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.415 sec to read coadd-5-20085-thru20210608.fits at 2022-07-06T19:15:15.419632
# INFO:spectra.py:291:read_spectra: iotime 0.523 sec to read spectra-5-1247-thru20210608.fits at 2022-07-06T19:15:22.370822
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-5-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-5-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-5-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.460 sec to read coadd-5-1247-thru20210608.fits at 2022-07-06T19:15:24.418334
# INFO:spectra.py:291:read_spectra: iotime 0.627 sec to read spectra-0-1247-thru20210608.fits at 2022-07-06T19:15:31.427202
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-0-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-0-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-0-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.405 sec to read coadd-0-1247-thru20210608.fits at 2022-07-06T19:15:33.432963
# INFO:spectra.py:291:read_spectra: iotime 0.577 sec to read spectra-4-1247-thru20210608.fits at 2022-07-06T19:15:40.239997
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-4-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-4-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-4-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.547 sec to read coadd-4-1247-thru20210608.fits at 2022-07-06T19:15:42.380699
# INFO:spectra.py:291:read_spectra: iotime 0.551 sec to read spectra-9-1247-thru20210608.fits at 2022-07-06T19:15:49.179819
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-9-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-9-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-9-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.490 sec to read coadd-9-1247-thru20210608.fits at 2022-07-06T19:15:51.230251
# INFO:spectra.py:291:read_spectra: iotime 0.654 sec to read spectra-1-1247-thru20210608.fits at 2022-07-06T19:15:58.243493
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-1-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-1-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-1-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.594 sec to read coadd-1-1247-thru20210608.fits at 2022-07-06T19:16:00.411675
# INFO:spectra.py:291:read_spectra: iotime 0.629 sec to read spectra-2-1247-thru20210608.fits at 2022-07-06T19:16:07.204128
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-2-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-2-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-2-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.612 sec to read coadd-2-1247-thru20210608.fits at 2022-07-06T19:16:09.444814
# INFO:spectra.py:291:read_spectra: iotime 0.500 sec to read spectra-8-1247-thru20210608.fits at 2022-07-06T19:16:16.409202
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-8-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-8-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-8-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.596 sec to read coadd-8-1247-thru20210608.fits at 2022-07-06T19:16:18.570094
# INFO:spectra.py:291:read_spectra: iotime 0.459 sec to read spectra-3-1247-thru20210608.fits at 2022-07-06T19:16:25.332854
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-3-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-3-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-3-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.478 sec to read coadd-3-1247-thru20210608.fits at 2022-07-06T19:16:27.573412
# INFO:spectra.py:291:read_spectra: iotime 0.582 sec to read spectra-7-1247-thru20210608.fits at 2022-07-06T19:16:34.708618
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-7-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-7-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-7-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.614 sec to read coadd-7-1247-thru20210608.fits at 2022-07-06T19:16:36.987886
# INFO:spectra.py:291:read_spectra: iotime 0.408 sec to read spectra-6-1247-thru20210608.fits at 2022-07-06T19:16:43.788992
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1247/20210608/coadd-6-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1247/20210608/coadd-6-1247-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1247/20210608/coadd-6-1247-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.408 sec to read coadd-6-1247-thru20210608.fits at 2022-07-06T19:16:45.817063
# INFO:spectra.py:291:read_spectra: iotime 0.506 sec to read spectra-8-1421-thru20210608.fits at 2022-07-06T19:16:52.570945
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-8-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-8-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-8-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.434 sec to read coadd-8-1421-thru20210608.fits at 2022-07-06T19:16:54.606254
# INFO:spectra.py:291:read_spectra: iotime 0.377 sec to read spectra-5-1421-thru20210608.fits at 2022-07-06T19:17:01.371782
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-5-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-5-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-5-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.456 sec to read coadd-5-1421-thru20210608.fits at 2022-07-06T19:17:03.598386
# INFO:spectra.py:291:read_spectra: iotime 0.533 sec to read spectra-6-1421-thru20210608.fits at 2022-07-06T19:17:10.460566
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-6-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-6-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-6-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.441 sec to read coadd-6-1421-thru20210608.fits at 2022-07-06T19:17:12.422029
# INFO:spectra.py:291:read_spectra: iotime 0.406 sec to read spectra-0-1421-thru20210608.fits at 2022-07-06T19:17:19.060774
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-0-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-0-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-0-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.354 sec to read coadd-0-1421-thru20210608.fits at 2022-07-06T19:17:21.004695
# INFO:spectra.py:291:read_spectra: iotime 0.479 sec to read spectra-9-1421-thru20210608.fits at 2022-07-06T19:17:27.782491
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-9-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-9-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-9-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.427 sec to read coadd-9-1421-thru20210608.fits at 2022-07-06T19:17:29.818689
# INFO:spectra.py:291:read_spectra: iotime 0.738 sec to read spectra-2-1421-thru20210608.fits at 2022-07-06T19:17:36.827685
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-2-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-2-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-2-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.343 sec to read coadd-2-1421-thru20210608.fits at 2022-07-06T19:17:38.944373
# INFO:spectra.py:291:read_spectra: iotime 0.439 sec to read spectra-3-1421-thru20210608.fits at 2022-07-06T19:17:45.808469
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-3-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-3-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-3-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.409 sec to read coadd-3-1421-thru20210608.fits at 2022-07-06T19:17:47.833354
# INFO:spectra.py:291:read_spectra: iotime 0.454 sec to read spectra-7-1421-thru20210608.fits at 2022-07-06T19:17:54.737175
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-7-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-7-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-7-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.411 sec to read coadd-7-1421-thru20210608.fits at 2022-07-06T19:17:57.339320
# INFO:spectra.py:291:read_spectra: iotime 0.591 sec to read spectra-4-1421-thru20210608.fits at 2022-07-06T19:18:04.689415
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-4-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-4-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-4-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.422 sec to read coadd-4-1421-thru20210608.fits at 2022-07-06T19:18:06.749605
# INFO:spectra.py:291:read_spectra: iotime 1.011 sec to read spectra-1-1421-thru20210608.fits at 2022-07-06T19:18:14.555975
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1421/20210608/coadd-1-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1421/20210608/coadd-1-1421-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1421/20210608/coadd-1-1421-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.750 sec to read coadd-1-1421-thru20210608.fits at 2022-07-06T19:18:16.990853
# INFO:spectra.py:291:read_spectra: iotime 0.614 sec to read spectra-4-1258-thru20210608.fits at 2022-07-06T19:18:24.247428
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1258/20210608/coadd-4-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1258/20210608/coadd-4-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1258/20210608/coadd-4-1258-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.505 sec to read coadd-4-1258-thru20210608.fits at 2022-07-06T19:18:26.341372
# INFO:spectra.py:291:read_spectra: iotime 0.573 sec to read spectra-7-1258-thru20210608.fits at 2022-07-06T19:18:33.608496
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1258/20210608/coadd-7-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1258/20210608/coadd-7-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1258/20210608/coadd-7-1258-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.634 sec to read coadd-7-1258-thru20210608.fits at 2022-07-06T19:18:35.839825
# INFO:spectra.py:291:read_spectra: iotime 0.965 sec to read spectra-9-1258-thru20210608.fits at 2022-07-06T19:18:43.522152
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1258/20210608/coadd-9-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1258/20210608/coadd-9-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1258/20210608/coadd-9-1258-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.962 sec to read coadd-9-1258-thru20210608.fits at 2022-07-06T19:18:46.091518
# INFO:spectra.py:291:read_spectra: iotime 0.615 sec to read spectra-0-1258-thru20210608.fits at 2022-07-06T19:18:53.516900
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1258/20210608/coadd-0-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1258/20210608/coadd-0-1258-thru20210608.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1258/20210608/coadd-0-1258-thru20210608.fits
# INFO:spectra.py:291:read_spectra: iotime 0.445 sec to read coadd-0-1258-thru20210608.fits at 2022-07-06T19:18:55.519158
# INFO:spectra.py:291:read_spectra: iotime 0.475 sec to read spectra-2-1258-thru20210608.fits at 2022-07-06T19:19:02.397527
# ...
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-2-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-2-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.277 sec to read coadd-2-20821-thru20210611.fits at 2022-07-06T20:20:40.420910
# INFO:spectra.py:291:read_spectra: iotime 0.370 sec to read spectra-7-20821-thru20210611.fits at 2022-07-06T20:20:47.239624
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-7-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-7-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-7-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.286 sec to read coadd-7-20821-thru20210611.fits at 2022-07-06T20:20:49.092337
# INFO:spectra.py:291:read_spectra: iotime 0.371 sec to read spectra-0-20821-thru20210611.fits at 2022-07-06T20:20:55.875809
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-0-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-0-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-0-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.824 sec to read coadd-0-20821-thru20210611.fits at 2022-07-06T20:20:58.281800
# INFO:spectra.py:291:read_spectra: iotime 0.406 sec to read spectra-5-20821-thru20210611.fits at 2022-07-06T20:21:05.102175
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-5-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-5-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-5-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.337 sec to read coadd-5-20821-thru20210611.fits at 2022-07-06T20:21:07.004289
# INFO:spectra.py:291:read_spectra: iotime 0.730 sec to read spectra-4-20821-thru20210611.fits at 2022-07-06T20:21:14.397784
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-4-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-4-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-4-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.307 sec to read coadd-4-20821-thru20210611.fits at 2022-07-06T20:21:16.542838
# INFO:spectra.py:291:read_spectra: iotime 0.316 sec to read spectra-8-20821-thru20210611.fits at 2022-07-06T20:21:23.392568
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-8-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-8-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-8-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.948 sec to read coadd-8-20821-thru20210611.fits at 2022-07-06T20:21:25.918866
# INFO:spectra.py:291:read_spectra: iotime 0.337 sec to read spectra-6-20821-thru20210611.fits at 2022-07-06T20:21:32.533038
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-6-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-6-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-6-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.291 sec to read coadd-6-20821-thru20210611.fits at 2022-07-06T20:21:34.445654
# INFO:spectra.py:291:read_spectra: iotime 0.633 sec to read spectra-1-20821-thru20210611.fits at 2022-07-06T20:21:41.925802
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-1-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-1-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-1-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.277 sec to read coadd-1-20821-thru20210611.fits at 2022-07-06T20:21:43.749689
# INFO:spectra.py:291:read_spectra: iotime 0.482 sec to read spectra-3-20821-thru20210611.fits at 2022-07-06T20:21:50.733970
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/20821/20210611/coadd-3-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/20821/20210611/coadd-3-20821-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/20821/20210611/coadd-3-20821-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.521 sec to read coadd-3-20821-thru20210611.fits at 2022-07-06T20:21:53.081705
# INFO:spectra.py:291:read_spectra: iotime 0.466 sec to read spectra-6-1134-thru20210611.fits at 2022-07-06T20:22:00.127145
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-6-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-6-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-6-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.358 sec to read coadd-6-1134-thru20210611.fits at 2022-07-06T20:22:02.262549
# INFO:spectra.py:291:read_spectra: iotime 0.450 sec to read spectra-0-1134-thru20210611.fits at 2022-07-06T20:22:09.124743
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-0-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-0-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-0-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.350 sec to read coadd-0-1134-thru20210611.fits at 2022-07-06T20:22:11.152829
# INFO:spectra.py:291:read_spectra: iotime 0.658 sec to read spectra-5-1134-thru20210611.fits at 2022-07-06T20:22:18.522784
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-5-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-5-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-5-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.390 sec to read coadd-5-1134-thru20210611.fits at 2022-07-06T20:22:20.625417
# INFO:spectra.py:291:read_spectra: iotime 0.583 sec to read spectra-3-1134-thru20210611.fits at 2022-07-06T20:22:27.841882
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-3-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-3-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-3-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.804 sec to read coadd-3-1134-thru20210611.fits at 2022-07-06T20:22:30.539215
# INFO:spectra.py:291:read_spectra: iotime 0.884 sec to read spectra-4-1134-thru20210611.fits at 2022-07-06T20:22:38.468334
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-4-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-4-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-4-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.374 sec to read coadd-4-1134-thru20210611.fits at 2022-07-06T20:22:40.510093
# INFO:spectra.py:291:read_spectra: iotime 0.418 sec to read spectra-8-1134-thru20210611.fits at 2022-07-06T20:22:47.446012
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-8-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-8-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-8-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.443 sec to read coadd-8-1134-thru20210611.fits at 2022-07-06T20:22:49.557277
# INFO:spectra.py:291:read_spectra: iotime 1.033 sec to read spectra-2-1134-thru20210611.fits at 2022-07-06T20:22:58.093764
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-2-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-2-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-2-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.811 sec to read coadd-2-1134-thru20210611.fits at 2022-07-06T20:23:00.534872
# INFO:spectra.py:291:read_spectra: iotime 0.484 sec to read spectra-7-1134-thru20210611.fits at 2022-07-06T20:23:07.787243
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-7-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-7-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-7-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.727 sec to read coadd-7-1134-thru20210611.fits at 2022-07-06T20:23:10.151953
# INFO:spectra.py:291:read_spectra: iotime 0.601 sec to read spectra-1-1134-thru20210611.fits at 2022-07-06T20:23:17.168773
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1134/20210611/coadd-1-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1134/20210611/coadd-1-1134-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1134/20210611/coadd-1-1134-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.665 sec to read coadd-1-1134-thru20210611.fits at 2022-07-06T20:23:19.521894
# INFO:spectra.py:291:read_spectra: iotime 1.611 sec to read spectra-6-1920-thru20210611.fits at 2022-07-06T20:23:28.013145
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-6-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-6-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-6-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.456 sec to read coadd-6-1920-thru20210611.fits at 2022-07-06T20:23:30.909046
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-6-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-6-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 1.004 sec to read spectra-3-1920-thru20210611.fits at 2022-07-06T20:23:38.311567
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-3-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-3-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-3-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.590 sec to read coadd-3-1920-thru20210611.fits at 2022-07-06T20:23:41.272916
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-3-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-3-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.950 sec to read spectra-1-1920-thru20210611.fits at 2022-07-06T20:23:48.629144
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-1-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-1-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-1-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.409 sec to read coadd-1-1920-thru20210611.fits at 2022-07-06T20:23:51.304930
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-1-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-1-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.950 sec to read spectra-7-1920-thru20210611.fits at 2022-07-06T20:23:58.613551
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-7-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-7-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-7-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.500 sec to read coadd-7-1920-thru20210611.fits at 2022-07-06T20:24:01.362387
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-7-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-7-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 1.325 sec to read spectra-5-1920-thru20210611.fits at 2022-07-06T20:24:09.025652
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-5-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-5-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-5-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.438 sec to read coadd-5-1920-thru20210611.fits at 2022-07-06T20:24:11.875471
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-5-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-5-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.960 sec to read spectra-0-1920-thru20210611.fits at 2022-07-06T20:24:19.205864
# /global/cfs/cdirs/desi/spectro/redux/everest/tiles/cumulative/1920/20210611/coadd-0-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/coadd-0-1920-thru20210611.fits
# /global/cfs/cdirs/desi/spectro/redux/guadalupe/tiles/cumulative/1920/20210611/coadd-0-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.429 sec to read coadd-0-1920-thru20210611.fits at 2022-07-06T20:24:21.842236
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210610/coadd-0-1920-thru20210610.fits
# /global/cfs/cdirs/desi/spectro/redux/backup-daily/tiles/cumulative/1920/20210611/coadd-0-1920-thru20210611.fits
# INFO:spectra.py:291:read_spectra: iotime 0.458 sec to read spectra-9-1920-thru20210611.fits at 2022-07-06T20:24:28.725367
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_22677/3915911600.py in <module>
#       8         ### daily_spectra, the precursor to current spectra, before coadding, to select night, unique target ids, and individual target ids
#       9         ### spectra.select functionality will not work once coadded with coaddition.coadd_cameras
# ---> 10         daily_spectra = ((read_spectra(current_filename)).select(nights = night))
#      11
#      12         table = Table.read(current_filename, format='fits',hdu=1, memmap=True)
#
# /global/common/software/desi/cori/desiconda/20211217-2.0.0/code/desispec/master/py/desispec/spectra.py in select(self, nights, exposures, bands, targets, fibers, invert, return_index)
#     363                 keep_selection = np.isin(self.fibermap[fm_var], fm_select)
#     364                 if sum(keep_selection) == 0:
# --> 365                     raise RuntimeError("no valid "+fm_var+" were selected!")
#     366                 keep_rows = keep_rows & keep_selection
#     367
#
# RuntimeError: no valid NIGHT were selected!

# %%
print(ra_dec)
# Out:
# (264.79014464874683, 33.735652626899395)

# %%
print(current_filename)
# Out:
# /global/project/projectdirs/desi/spectro/redux/daily/tiles/cumulative/1920/20210611/spectra-9-1920-thru20210611.fits

# %%
debug_spectra = read_spectra(current_filename)
# Out:
# INFO:spectra.py:291:read_spectra: iotime 0.617 sec to read spectra-9-1920-thru20210611.fits at 2022-07-07T11:25:57.412297

# %%
debug_spectra.fibermap
# Out:
# <Table length=500>
#      TARGETID     PETAL_LOC DEVICE_LOC LOCATION ... EXPID      MJD       TILEID
#       int64         int16     int32     int64   ... int32    float64     int32
# ----------------- --------- ---------- -------- ... ----- -------------- ------
# 39632957064875447         9        403     9403 ... 93280 59376.39914365   1920
# 39632957064872753         9        452     9452 ... 93280 59376.39914365   1920
# 39632957064875879         9        426     9426 ... 93280 59376.39914365   1920
# 39632962085456409         9        299     9299 ... 93280 59376.39914365   1920
#          -9647739         9        339     9339 ... 93280 59376.39914365   1920
# 39632962085455420         9        300     9300 ... 93280 59376.39914365   1920
# 39632962085457593         9        318     9318 ... 93280 59376.39914365   1920
# 39632957064875417         9        381     9381 ... 93280 59376.39914365   1920
# 39632957064874944         9        404     9404 ... 93280 59376.39914365   1920
# 39632957060682157         9        408     9408 ... 93280 59376.39914365   1920
#               ...       ...        ...      ... ...   ...            ...    ...
# 39632962077068973         9        220     9220 ... 93280 59376.39914365   1920
# 39632962077069567         9        188     9188 ... 93280 59376.39914365   1920
# 39632962077068251         9        238     9238 ... 93280 59376.39914365   1920
# 39632962081260040         9        252     9252 ... 93280 59376.39914365   1920
# 39632957056487439         9        291     9291 ... 93280 59376.39914365   1920
# 39632962081261432         9        200     9200 ... 93280 59376.39914365   1920
# 39632957056485654         9        256     9256 ... 93280 59376.39914365   1920
# 39632962081260209         9        201     9201 ... 93280 59376.39914365   1920
# 39632962081260354         9        234     9234 ... 93280 59376.39914365   1920
# 39632962081263280         9        214     9214 ... 93280 59376.39914365   1920
